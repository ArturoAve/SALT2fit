# %% [markdown]
# # Code to convert from Andy's "wstd" LC files to SNANA format
#
# Python 2.7
#
# ## Notes
#
# - Input files:
#     - Wstd files
#     - metadata file with (snname, zhelio, e_zhel, zcmb, e_zcmb, sample, ra, dec)
#     - metadata file with (snname, TBmax, err_TBmax, EBV_MW, err_EBV_MW)
#
# - The output files will be saved in a subfolder called 'snana'

# %%
import numpy as np
import glob # To read the files in my directory
import os # To use command line like instructions
import datetime # Get the current date and time

cc = 299792.458  # Speed of light (km/s)

#--------------------------------------------------------60
code_created_by = 'Arturo_Avelino'
# On date: 2017.01.10 (yyyy.mm.dd)
code_name = '03_WstdAndy_to_SNANA.ipynb'
code_version = '0.1.9'
code_last_update = '2019.07.03'
code_location = 'https://github.com/ArturoAvelino/SALT2fit/blob/master/03_WstdAndy_to_SNANA.py'

# %%
##############################################################################80

# %% [markdown]
# # User

# %%
# Directory where Andy's wstd files to be converted are located:
dirwstd = '/Users/arturo/Documents/Research/Workplace/BayeSED/andy_comp/Wstd_to_SNANA/Wstd/'

# List of SNe filenames to be converted.
file_listSNe = 'List_SNe_Notes_.txt'

# Location of the list file:
dirfilelist = '/Users/arturo/Documents/Research/Workplace/BayeSED/andy_comp/NoShared/'

#--------------------------------------------------------60

# String to be printed in the 'SURVEY' line in SNANA files.
# NOTE: For low-z CSP data set "Survey = 'CSP' ". This allows to fit the data in 
# SNANA/SALT2 with no issues when using the CSP kcorr file in SNANA.
# Options:
#      'LOWZ' for low-z CfA and Others LCs.
#      'CSP' for low-z CSP LCs.
Survey = 'LOWZ'  

#--------------------------------------------------------60

# Directory to save the output:
## DirSaveOutput = dirwstd+'snana/'
DirSaveOutput = '/Users/arturo/Documents/Research/Workplace/BayeSED/andy_comp/Wstd_to_SNANA/snana/'

# %% [markdown]
# #### Filter's name matching between Andy and SNANA

# %%
# Filter's name matching between Andy and SNANA

# Write -all- the filter's name in the line "FILTERS: " in the 
# SNANA-format LC file? If 'False', then it will be written the 
# filters listed in the list 'filterListToConvert' below only. If 
# 'True', then it will write down -all- the filters names. For those
# that are not in the list 'filterListToConvert' then it will
# write the filter's name using Andy's original names.
write_all_filters = True 

# List of filter names that will be converted their names from Andy's 
# to SNANA convention's names.
# Any other filter not listed here will not be written in the
# line "FILTERS: " in the SNANA-like output file, 
# unless "write_all_filters = True".

# filterListToConvert = ['r_prime', 'i_prime', 
#                     'B_CTIO1p3m','V_CTIO1p3m','R_CTIO1p3m','I_CTIO1p3m',
#                     'u_CSP', 'g_CSP', 'r_CSP', 'i_CSP', 'B_CSP', 'V_CSP',
#                     'B', 'V', 'R', 'I']

filterListToConvert = ['null']

#--------------------------------------------------------60
# Create a dictionary with the conversion names from the above list.

# The dictionary structure is: (filter_Andy: filter_SNANA)
FilterNameConversion_dict = {}

FilterNameConversion_dict['null'] = ['null']

# FilterNameConversion_dict['r_prime'] = ['r']
# FilterNameConversion_dict['i_prime'] = ['i']
# FilterNameConversion_dict['B_CTIO1p3m'] = ['B'] 
# FilterNameConversion_dict['V_CTIO1p3m'] = ['V'] 
# FilterNameConversion_dict['R_CTIO1p3m'] = ['R'] 
# FilterNameConversion_dict['I_CTIO1p3m'] = ['I'] 
# FilterNameConversion_dict['u_CSP'] = ['u']
# FilterNameConversion_dict['g_CSP'] = ['g']
# FilterNameConversion_dict['r_CSP'] = ['r']
# FilterNameConversion_dict['i_CSP'] = ['i']
# FilterNameConversion_dict['B_CSP'] = ['B']
# FilterNameConversion_dict['V_CSP'] = ['o']
# 
# FilterNameConversion_dict['B'] = ['B'] 
# FilterNameConversion_dict['V'] = ['V'] 
# FilterNameConversion_dict['R'] = ['R'] 
# FilterNameConversion_dict['I'] = ['I'] 

#--------------------------------------------------------60
# Rename the output files using the first 'TrimFileName' characters 
# of the datafile.

# "-4" = use the full name of the file except the extension characters ".dat"
TrimFileName = -4 
# TrimFileName = 18 

# Print on the output files the date-time and script used to 
# create them?
print_date_scriptName = True

# %%
##############################################################################80

# %% [markdown]
# -------

# %% [markdown]
# # Automatic

# %%
#- Force the creation of the directory to save the outputs.
#- "If the subdirectory does not exist then create it"
if not os.path.exists(DirSaveOutput): os.makedirs(DirSaveOutput)

# %% [markdown]
# #### Function to identify string or number

# %%
# Function to identify if a string is an integer number or a letter.
# This will be used in the dictionary construction to properly read some SN names.

def is_number(s):
    try:
        int(s)
        return True
    except ValueError:
        return False

# Tests
print '#', is_number('5'), is_number('e')
# True False
# Out:
# # True False

# %%
# Get the current date and time
# Read the time and date now
now = datetime.datetime.now()

# %% [markdown]
# ## Input metadata

# %% [markdown]
# ### Read metadata (snname, zhelio, e_zhel, zcmb, e_zcmb, sample, ra, dec)

# %%
MetadataFile = 'carrick_Flow_corrections_snnames_v1.txt'
DirMetadata = '/Users/arturo/Documents/Research/Workplace/BayeSED/andy_comp/NoShared/'

# Reading the metadata file
infoSNe_data = np.genfromtxt(DirMetadata+MetadataFile,
                            dtype=['S17', float,float, 'S40',float,float,
                                   float,float,float,float,'S16', int ])

# Create a dictionary:
# {snname: zhelio, e_zhel, zcmb, e_zcmb, zcmbFlow, 
#          e_zcmbFlow, code, ra, dec}

InfoSN_dict = {infoSNe_data['f0'][i]: [
                infoSNe_data['f4'][i]/cc, infoSNe_data['f5'][i]/cc,
                infoSNe_data['f6'][i]/cc, infoSNe_data['f7'][i]/cc,
                infoSNe_data['f8'][i]/cc, infoSNe_data['f9'][i]/cc,
                infoSNe_data['f11'][i],
                infoSNe_data['f1'][i], infoSNe_data['f2'][i] ]
                for i in range(len(infoSNe_data)) }


#--------------------------------------------------------60
# Just check that the dictionary works fine.

InfoSN_dict['sn1998bu']
# [0.0029620491653595902,
#  3.3356409519815205e-06,
#  0.0023683050759068795,
#  8.6726664751519533e-05,
#  0.003138838135814611,
#  0.00050034614279722807,
#  1,
#  161.69166999999999,
#  11.835279999999999]
# Out:
# [0.00296204916535959,
#  3.3356409519815205e-06,
#  0.0025250802006500112,
#  0.00023349486663870643,
#  0.000807225110379528,
#  0.0005003461427972281,
#  1,
#  161.69167,
#  11.83528]

# %%
#-----------------------------------------------------------------------------80

# %% [markdown]
# ### Read metadata (t_Bmax, EBV_MW)

# %%
MetadataFile2 = 'tBmax_EBVMW_all.txt'
DirMetadata2 = '/Users/arturo/Documents/Research/Workplace/BayeSED/andy_comp/NoShared/'

DistMu_np = np.genfromtxt(DirMetadata2+ MetadataFile2,
                             dtype=['S16',float,float,float,float])

#----- Create a dictionary -----
# (snname: TBmax, err_TBmax, EBV_MW, err_EBV_MW)

DistMu_dict ={}
for i in range(len(DistMu_np)):
    
    # Sn name
    snName_1 = DistMu_np['f0'][i]
    
    TBmax_int_1 = DistMu_np['f1'][i]
    
    # add 53000 MJD to tBmax of some CSP SNe.
    if TBmax_int_1 < 4000:
        TBmax_int = TBmax_int_1 + 53000
    else: TBmax_int = TBmax_int_1
    
    err_TBmax_int = DistMu_np['f2'][i]
    
    EBV_MW_int     = DistMu_np['f3'][i]
    err_EBV_MW_int = DistMu_np['f4'][i]
    
    DistMu_dict[snName_1] = [TBmax_int, err_TBmax_int, EBV_MW_int, err_EBV_MW_int]

#--------------------------------------------------------60
# Just check that the dictionary works fine.

print '#', DistMu_dict['sn1998bu']
# # [50953.113987516, 0.0811452888, 0.0217, 0.0002]
# Out:
# # [50953.113987516, 0.0811452888, 0.0217, 0.0002]

# %% [markdown]
# #### Convert fluxes to zeropoint = 27.5 (default in SNANA)

# %%
zp_snana = 27.5

def flux_snana(flux_old, zp_Andy): 
    
    zp_snana = 27.5
    flux_new = flux_old * 10**(0.4*(zp_snana - zp_Andy))
    
    return flux_new

print '# Test:', flux_snana(587.41, 25)
# Test: 5874.1
# Out:
# # Test: 5874.1

# %%
#-----------------------------------------------------------------------------80

# %% [markdown]
# -----

# %% [markdown]
# # Read/convert Andy's wstd file to SNANA-format text file

# %%
# Read the names of all the photometry files to be converted

the_list_np = np.genfromtxt(dirfilelist+file_listSNe, dtype=['S170'])

# Convert the numpy array to list:
the_list = the_list_np['f0'].tolist()

print '# %s SNe in this list.'%len(the_list)
# 341 SNe in this list.
# Out:
# # 341 SNe in this list.

# %%
##############################################################################80

# %% [markdown]
# ### Main loop

# %%
zp_Andy = 25  # Andy's zeropoint: 25 mag 

count_lcs = 0 # count LCs converted to SNANA format

# Loop over Andy's wstd LC files.
for wstdFile in the_list:
    
    wstd_np = np.genfromtxt(dirwstd+wstdFile, usecols=[1,2,3,4,5] , 
                        dtype=[float,'S14', float, float, float])
    
    #====================================================
    
    # Create the variable "snName" containing the first 8 (or 7) 
    # letters of the SNe file name
    try:
        if   wstdFile[7] == '_': 
            snName = wstdFile[:7]  # To read correctly, e.g., "sn2011B_"
        elif wstdFile[7] != '_':
            # To read correctly, e.g., "snf20080514-002"
            if is_number(wstdFile[7]): snName = wstdFile[:15] 
            else: snName = wstdFile[:8]  # To read correctly, e.g., "sn1998bu"  
    except: snName = wstdFile[:6]  # To read correctly, e.g., "sn2011B"

    #-------------------------------
    # Create a list of filters that are in a given photometric file:

    # Reset
    ListFilters = []
    filtername_int_2 = ''; filtersnana_2 = '';
    
    # Loop over the photometry:
    for j in range(len(wstd_np)):

        # Read the filter's name
        filtername_int_2 = wstd_np['f1'][j]

        # Convert the filter's name to SNANA
        if filtername_int_2 in filterListToConvert:
            filtersnana_2 = FilterNameConversion_dict[filtername_int_2][0]
        else:
            if write_all_filters:
                filtersnana_2 = filtername_int_2

        # Create a list of unique filters 
        if filtersnana_2 not in ListFilters:
            ListFilters += [filtersnana_2]

    # print '# Filters in this file: ',ListFilters

    #---- Create a single string with the name of all the filters ----
    # This will be written in the SNANA-format text file 
    # in the row "FILTERS: "

    ListFiltersToPrint = ''
    for name in ListFilters:
        ListFiltersToPrint = ListFiltersToPrint+name

    # print '# Text to print in the field FILTERS:', ListFiltersToPrint
    
    #--------------------------------------
    # Determine the number of observations based on the filters
    # to be considered
    
    NOBS = 0
    
    # Loop over the photometry:
    for j2 in range(len(wstd_np)):
        # Read the filter's name
        filtername_int_2 = wstd_np['f1'][j2]
        
        if write_all_filters:
            NOBS += 1
        elif filtername_int_2 in filterListToConvert:
            NOBS += 1
    
    #====================================================
    
    # Read the time and date right now
    now = datetime.datetime.now()

    snana_file = open(DirSaveOutput+wstdFile[:TrimFileName]+'_snana.dat', 'w')

    text_line_1 = '#'+'-'*60+'\n'
    snana_file.write('#      %s \n'%snName)
    snana_file.write("# Andy Friedman's Wstd file converted to SNANA-like format. \n")
    snana_file.write('# Source file: %s \n'%wstdFile)
    snana_file.write("# Metadata information from: %s \n"%MetadataFile)
    snana_file.write("# Photometry and metadata compiled by Andrew S. Friedman (UCSD).\n")
    # snana_file.write("# Located at: \n")
    # snana_file.write("# %s \n"%DirMetadata)
    snana_file.write("# write_all_filters = %s. \n"%write_all_filters)
    snana_file.write("# Zeropoint of the converted SNANA file: %s mag\n"%zp_snana)
    
    snana_file.write(text_line_1)
    snana_file.write('# Data table created by: %s\n'%code_created_by)
    if print_date_scriptName: 
        text_01 = now.strftime("%Y.%m.%d (yyyy.mm.dd); %H:%M hrs (ET).")
        snana_file.write('# On date: %s \n'%text_01)
        snana_file.write('# Script used: %s \n'%code_name)
        snana_file.write('# Script version: %s \n'%code_version)
        # snana_file.write('# Script URL location:\n')
        # snana_file.write('# %s\n'%code_location)
    snana_file.write(text_line_1)

    #---------------------

    #   SNANA header

    # Create a final dictionary. It has the form of:
    # (snname: zhelio, err_zhelio, zcmb, err_zcmb) 
    
    zhel = InfoSN_dict[snName][0]
    err_zhel = InfoSN_dict[snName][1]
    
    # Flag to determine the appropiate z_cmb:
    flag_zcmb  = InfoSN_dict[snName][6]
    if flag_zcmb > 0.1:
        zcmb     = InfoSN_dict[snName][2]
        err_zcmb = InfoSN_dict[snName][3]
    else:
        zcmb     = InfoSN_dict[snName][4]
        err_zcmb = InfoSN_dict[snName][5]

    RA       = InfoSN_dict[snName][7]
    DEC      = InfoSN_dict[snName][8]
    
    EBV_MW  = DistMu_dict[snName][2]
    PEAKMJD = DistMu_dict[snName][0]

    snana_file.write('SURVEY: %s \n'%Survey)
    snana_file.write('SNID: %s \n'%snName[2:])
    snana_file.write('IAUC: %s \n'%snName[2:])
    snana_file.write('RA: %s deg \n'%RA)
    snana_file.write('DECL: %s deg \n'%DEC)
    snana_file.write('MWEBV: %s MW E(B-V) \n'%EBV_MW)
    snana_file.write('REDSHIFT_HELIO: %1.5f +- %1.6f (HEL)\n'%(zhel, err_zhel))
    snana_file.write('REDSHIFT_CMB: %1.5f +- %1.6f (CMB)\n'%(zcmb, err_zcmb))
    snana_file.write('REDSHIFT_FINAL: %1.5f +- %1.6f (CMB)\n'%(zcmb, err_zcmb))
    snana_file.write('SEARCH_PEAKMJD: %.3f \n'%PEAKMJD)
    snana_file.write('FILTERS: %s \n'%ListFiltersToPrint)

    #---------------------

    snana_file.write(text_line_1)
    # old. snana_file.write('NOBS: %s \n'%len(wstd_np))
    snana_file.write('NOBS: %s \n'%NOBS)
    snana_file.write('NVAR: 7 \n')
    snana_file.write('VARLIST:  MJD  FLT           FIELD       \
FLUXCAL         FLUXCALERR  MAG  MAGERR  \n')

    #---------------------

    # Loop over photometry:
    for i in range(len(wstd_np)):

        filtername_int1 = wstd_np['f1'][i]

        if filtername_int1 in filterListToConvert:
            filtersnana = FilterNameConversion_dict[filtername_int1][0]
        else: filtersnana = filtername_int1

        flux_old         = wstd_np['f2'][i]
        err_flux_old_low = wstd_np['f3'][i]
        err_flux_old_hig = wstd_np['f4'][i]

        flux_new         = flux_snana(flux_old, zp_Andy)
        err_flux_new_low = flux_snana(err_flux_old_low, zp_Andy)
        err_flux_new_hig = flux_snana(err_flux_old_hig, zp_Andy)

        average_errorFlux = (err_flux_new_low + err_flux_new_hig)/2

        # Write the line in the text file
        if write_all_filters:
            snana_file.write('OBS: %.3f  %-12s NULL  %15.4f \
%15.4f    0     0 \n'%(wstd_np['f0'][i], 
                        filtersnana, flux_new, average_errorFlux))
            
        elif filtername_int1 in filterListToConvert:
            snana_file.write('OBS: %.3f  %-12s NULL  %15.4f \
%15.4f    0     0 \n'%(wstd_np['f0'][i], 
                        filtersnana, flux_new, average_errorFlux))

    snana_file.write('END:')
    snana_file.close();

    count_lcs += 1
    print wstdFile[0:40]
    
#--------------------------------------------------------60
print '\n# All %s LCs converted smoothly'%count_lcs
# Out:
# sn1998bu__U_69_B_97_V_110_R_87_I_108_J_1
# sn1999aa__B_19_V_18_R_16_I_16__LOSS_gane
# sn1999aa__U_21_B_23_V_21_R_21_I_22__CfA2
# sn1999aa__U_24_B_58_V_57_R_53_I_53_J_4_K
# sn1999cl__B_22_V_22_R_21_I_21__LOSS_gane
# sn1999cl__U_8_B_7_V_9_R_8_I_8__CfA2_jha0
# sn1999cl__U_8_B_15_V_17_R_16_I_16_J_6_H_
# sn1999cp__B_5_V_5_R_5_I_5_J_2_H_2_K_2__L
# sn1999cp__B_27_V_29_R_28_I_27__LOSS_gane
# sn1999ee__U_45_B_118_V_126_R_53_I_109_J_
# sn1999ek__U_2_B_5_V_7_R_6_I_6__CfA2_jha0
# sn1999ek__U_2_B_38_V_39_R_37_I_37_J_14_H
# sn1999gp__B_23_V_23_R_21_I_20__LOSS_gane
# sn1999gp__U_11_B_11_V_11_R_10_I_11__CfA2
# sn1999gp__U_11_B_47_V_49_R_44_I_39_J_3_H
# sn2000bh__B_12_V_12_R_9_I_11_Y_CSP_6_J_C
# sn2000bk__B_9_V_9_R_9_I_9_J_18_H_16__LCO
# sn2000ca__U_6_B_18_V_18_R_18_I_18_J_CSP_
# sn2000ce__U_6_B_6_V_6_R_6_I_6__CfA2_jha0
# sn2000ce__U_6_B_13_V_13_R_13_I_13_J_3_H_
# sn2000E__U_5_B_27_V_26_R_27_I_9_J_16_H_1
# sn2001ba__B_30_V_34_I_33_J_CSP_15_H_CSP_
# sn2001bt__B_22_V_23_R_20_I_22_J_21_H_21_
# sn2001cn__U_3_B_25_V_25_R_25_I_25_J_19_H
# sn2001cz__B_14_V_14_R_12_I_12_J_12_H_12_
# sn2001el__U_20_B_44_V_44_R_39_I_39_J_33_
# sn2002bo__B_33_V_33_R_34_I_31__LOSS_gane
# sn2002bo__U_12_B_17_V_17_R_21_I_19__CfA3
# sn2002bo__U_16_B_53_V_57_R_46_I_60_J_14_
# sn2002dj__B_14_V_14_R_13_I_13__LOSS_gane
# sn2002dj__U_4_B_12_V_10_R_11_I_12__CfA3_
# sn2002dj__U_13_B_18_V_20_R_20_I_19_J_21_
# sn2002fk__B_39_V_39_R_43_I_43__LOSS_gane
# sn2002fk__U_12_B_21_V_22_R_15_I_18_J_24_
# sn2002fk__U_12_B_21_V_25_R_23_I_24__CfA3
# sn2003cg__B_20_V_24_R_23_I_22__LOSS_gane
# sn2003cg__U_5_B_9_V_14_R_14_I_13__CfA3_h
# sn2003cg__U_34_B_53_V_57_R_59_I_57_J_11_
# sn2003du__B_38_V_38_R_38_I_38__LOSS_gane
# sn2003du__U_16_B_18_V_22_R_32_I_21__CfA3
# sn2003du__U_16_B_18_V_22_R_32_I_21_J_6_H
# sn2003hv__B_42_V_42_R_42_I_39__LOSS_gane
# sn2003hv__U_24_B_70_V_70_R_69_I_66_Y_15_
# sn2004ef__B_24_V_24_R_24_I_25__LOSS_gane
# sn2004ef__U_1_B_8_V_9_r_prime_7_i_prime_
# sn2004ef__u_CSP_34_B_CSP_42_g_CSP_47_V_C
# sn2004eo__B_32_V_32_R_32_I_33__LOSS_gane
# sn2004eo__J_11_H_9_K_11__ESO_pastorello0
# sn2004eo__u_CSP_36_B_CSP_38_g_CSP_34_V_C
# sn2004ey__B_14_V_15_R_16_I_16__LOSS_gane
# sn2004ey__u_CSP_25_B_CSP_30_g_CSP_26_V_C
# sn2004gs__B_13_V_13_R_13_I_12__LOSS_gane
# sn2004gs__u_CSP_19_B_CSP_43_g_CSP_49_V_C
# sn2004S__B_19_V_18_R_19_I_19__LOSS_ganes
# sn2004S__U_19_B_23_V_26_R_25_I_25_J_16_H
# sn2005al__u_CSP_35_B_CSP_35_g_CSP_35_V_C
# sn2005am__B_26_V_27_R_27_I_27__LOSS_gane
# sn2005am__U_10_B_24_V_26_r_prime_23_i_pr
# sn2005am__u_CSP_37_B_CSP_35_g_CSP_34_V_C
# sn2005bo__B_15_V_16_R_17_I_17__LOSS_gane
# sn2005bo__J_15_H_16_K_13__CfAIR2_friedma
# sn2005bo__u_CSP_8_B_CSP_9_g_CSP_9_V_CSP_
# sn2005cf__B_55_V_55_R_56_I_53__LOSS_gane
# sn2005cf__J_17_H_17_K_15__CfAIR2_friedma
# sn2005cf__U_36_B_19_V_21_r_prime_17_i_pr
# sn2005el__B_26_V_25_R_26_I_26__LOSS_gane
# sn2005el__J_35_H_34_K_24__CfAIR2_friedma
# sn2005el__U_55_B_39_V_55_r_prime_52_i_pr
# sn2005el__u_CSP_24_B_CSP_24_g_CSP_22_V_C
# sn2005eq__B_21_V_22_R_22_I_22__LOSS_gane
# sn2005eq__J_31_H_33_K_29__CfAIR2_friedma
# sn2005eq__U_22_B_24_V_33_r_prime_32_i_pr
# sn2005eq__u_CSP_19_B_CSP_27_g_CSP_27_V_C
# sn2005eu__B_16_V_17_R_17_I_16__LOSS_gane
# sn2005eu__B_16_V_25_r_prime_28_i_prime_2
# sn2005eu__J_23_H_23_K_14__CfAIR2_friedma
# sn2005hc__U_26_B_15_V_24_r_prime_22_i_pr
# sn2005hc__u_CSP_10_B_CSP_23_g_CSP_23_V_C
# sn2005iq__J_12_H_9_K_2__CfAIR2_friedman1
# sn2005iq__U_7_B_15_V_14_r_prime_15_i_pri
# sn2005iq__u_CSP_14_B_CSP_18_g_CSP_20_V_C
# sn2005kc__U_10_B_8_V_13_r_prime_11_i_pri
# sn2005kc__u_CSP_9_B_CSP_13_g_CSP_13_V_CS
# sn2005ki__U_18_B_21_V_26_r_prime_14_i_pr
# sn2005ki__u_CSP_30_B_CSP_44_g_CSP_47_V_C
# sn2005ku__u_CSP_3_B_CSP_5_g_CSP_6_V_CSP_
# sn2005ls__J_21_H_19_K_19__CfAIR2_friedma
# sn2005ls__U_12_B_14_V_19_r_prime_19_i_pr
# sn2005lu__U_5_B_6_V_12_r_prime_11_i_prim
# sn2005lu__u_CSP_6_B_CSP_17_g_CSP_10_V_CS
# sn2005M__B_19_V_20_R_20_I_20__LOSS_ganes
# sn2005M__U_6_B_4_V_6_r_prime_5_i_prime_5
# sn2005M__u_CSP_38_B_CSP_55_g_CSP_59_V_CS
# sn2005na__B_18_V_17_R_17_I_16__LOSS_gane
# sn2005na__J_13_H_4_K_10__CfAIR2_friedman
# sn2005na__U_13_B_13_V_21_r_prime_23_i_pr
# sn2005na__u_CSP_16_B_CSP_26_g_CSP_25_V_C
# sn2006ac__B_8_V_8_R_8_I_7__LOSS_ganeshal
# sn2006ac__J_22_H_15_K_16__CfAIR2_friedma
# sn2006ac__U_27_B_23_V_30_r_prime_33_i_pr
# sn2006ax__J_19_H_15_K_16__CfAIR2_friedma
# sn2006ax__U_37_B_23_V_23_r_prime_24_i_pr
# sn2006ax__u_CSP_18_B_CSP_25_g_CSP_22_V_C
# sn2006bh__u_CSP_22_B_CSP_25_g_CSP_24_V_C
# sn2006cp__B_15_V_14_R_15_I_15__LOSS_gane
# sn2006cp__J_5_H_5_K_3__CfAIR2_friedman15
# sn2006cp__U_6_B_7_V_8_r_prime_10_i_prime
# sn2006D__B_15_V_15_R_14_I_15__LOSS_ganes
# sn2006D__J_23_H_21_K_17__CfAIR2_friedman
# sn2006D__U_24_B_22_V_26_r_prime_29_i_pri
# sn2006D__u_CSP_32_B_CSP_39_g_CSP_38_V_CS
# sn2006ej__B_9_V_15_r_prime_14_i_prime_16
# sn2006ej__B_12_V_13_R_12_I_13__LOSS_gane
# sn2006ej__u_CSP_5_B_CSP_12_g_CSP_13_V_CS
# sn2006et__B_8_V_14_r_prime_11_i_prime_11
# sn2006et__u_CSP_19_B_CSP_23_g_CSP_26_V_C
# sn2006gj__U_5_B_8_V_13_r_prime_13_i_prim
# sn2006gj__u_CSP_4_B_CSP_12_g_CSP_19_V_CS
# sn2006gr__B_18_V_18_R_18_I_18__LOSS_gane
# sn2006gr__J_7_H_5_K_2__CfAIR2_friedman15
# sn2006gr__U_17_B_18_V_30_r_prime_34_i_pr
# sn2006hb__B_14_V_14_R_14_I_14__LOSS_gane
# sn2006hb__U_13_B_6_V_34_r_prime_31_i_pri
# sn2006hb__u_CSP_9_B_CSP_28_g_CSP_26_V_CS
# sn2006hx__u_CSP_5_B_CSP_9_g_CSP_11_V_CSP
# sn2006is__B_16_V_22_r_prime_22_i_prime_2
# sn2006is__u_CSP_13_B_CSP_28_g_CSP_27_V_C
# sn2006kf__B_14_V_21_r_prime_19_i_prime_1
# sn2006kf__u_CSP_9_B_CSP_17_g_CSP_16_V_CS
# sn2006le__B_14_V_15_R_15_I_15__LOSS_gane
# sn2006le__J_39_H_36_K_31__CfAIR2_friedma
# sn2006le__U_36_B_31_V_55_r_prime_53_i_pr
# sn2006lf__B_11_V_15_R_15_I_13__LOSS_gane
# sn2006lf__J_40_H_41_K_28__CfAIR2_friedma
# sn2006lf__U_3_B_24_V_34_r_prime_33_i_pri
# sn2006lu__u_CSP_6_B_CSP_21_g_CSP_26_V_CS
# sn2006N__J_14_H_12_K_7__CfAIR2_friedman1
# sn2006N__U_26_B_24_V_31_r_prime_30_i_pri
# sn2006ob__U_10_B_10_V_16_r_prime_17_i_pr
# sn2006ob__u_CSP_2_B_CSP_5_g_CSP_8_V_CSP_
# sn2006os__B_10_V_10_r_prime_11_i_prime_1
# sn2006os__u_CSP_4_B_CSP_9_g_CSP_13_V_CSP
# sn2006X__B_13_V_13_R_13_I_13__LOSS_ganes
# sn2006X__J_45_H_44_K_37__CfAIR2_friedman
# sn2006X__U_34_B_37_V_50_r_prime_51_i_pri
# sn2006X__u_CSP_19_B_CSP_35_g_CSP_34_V_CS
# sn2007A__B_4_V_4_r_prime_4_i_prime_4__Cf
# sn2007A__u_CSP_5_B_CSP_8_g_CSP_6_V_CSP_8
# sn2007af__B_39_V_39_R_38_I_37__LOSS_gane
# sn2007af__B_55_V_58_r_prime_55_i_prime_5
# sn2007af__u_CSP_24_B_CSP_27_g_CSP_24_V_C
# sn2007ai__B_9_V_12_r_prime_13_i_prime_14
# sn2007ai__u_CSP_6_B_CSP_15_g_CSP_15_V_CS
# sn2007as__u_CSP_9_B_CSP_18_g_CSP_19_V_CS
# sn2007bc__B_15_V_17_R_17_I_17__LOSS_gane
# sn2007bc__B_19_V_17_r_prime_15_i_prime_9
# sn2007bc__u_CSP_7_B_CSP_11_g_CSP_15_V_CS
# sn2007bd__B_10_V_12_r_prime_12_i_prime_1
# sn2007bd__u_CSP_8_B_CSP_12_g_CSP_12_V_CS
# sn2007bm__B_14_V_19_r_prime_19_i_prime_1
# sn2007bm__u_CSP_7_B_CSP_10_g_CSP_8_V_CSP
# sn2007ca__B_10_V_14_R_14_I_13__LOSS_gane
# sn2007ca__B_13_V_16_r_prime_15_i_prime_1
# sn2007ca__J_18_H_18_K_10__CfAIR2_friedma
# sn2007ca__u_CSP_8_B_CSP_12_g_CSP_12_V_CS
# sn2007co__B_22_V_24_R_24_I_24__LOSS_gane
# sn2007co__J_7_H_6_K_5__CfAIR2_friedman15
# sn2007co__U_19_B_23_V_28_r_prime_27_i_pr
# sn2007cq__B_22_V_23_R_23_I_23__LOSS_gane
# sn2007cq__B_26_V_29_r_prime_29_i_prime_2
# sn2007cq__J_6_H_6_K_6__CfAIR2_friedman15
# sn2007fb__J_2_H_2_K_1__CfAIR2_friedman15
# sn2007fb__U_6_B_28_V_29_r_prime_28_i_pri
# sn2007hj__B_23_V_23_R_24_I_23__LOSS_gane
# sn2007hj__U_15_B_33_V_39_r_prime_38_i_pr
# sn2007hj__u_CSP_13_B_CSP_26_g_CSP_27_V_C
# sn2007hx__u_CSP_2_B_CSP_10_g_CSP_11_V_CS
# sn2007jd__u_CSP_2_B_CSP_10_g_CSP_11_V_CS
# sn2007jg__U_6_B_22_V_26_r_prime_23_i_pri
# sn2007jg__u_CSP_7_B_CSP_17_g_CSP_15_V_CS
# sn2007le__B_19_V_26_r_prime_26_i_prime_2
# sn2007le__B_28_V_29_R_27_I_27__LOSS_gane
# sn2007le__J_35_H_31_K_25__CfAIR2_friedma
# sn2007le__u_CSP_21_B_CSP_25_g_CSP_23_V_C
# sn2007nq__B_14_V_17_r_prime_17_i_prime_1
# sn2007nq__J_3_H_2_K_3__CfAIR2_friedman15
# sn2007nq__u_CSP_6_B_CSP_21_g_CSP_23_V_CS
# sn2007on__u_CSP_33_B_CSP_31_g_CSP_17_V_C
# sn2007qe__B_13_V_11_R_13_I_12__LOSS_gane
# sn2007qe__B_43_V_24_r_prime_26_i_prime_2
# sn2007qe__J_8_H_8_K_7__CfAIR2_friedman15
# sn2007rx__B_11_V_13_r_prime_13_i_prime_1
# sn2007rx__J_5_H_5_K_5__CfAIR2_friedman15
# sn2007S__B_40_V_48_r_prime_50_i_prime_48
# sn2007S__J_29_H_27_K_25__CfAIR2_friedman
# sn2007S__u_CSP_12_B_CSP_18_g_CSP_18_V_CS
# sn2007so__u_CSP_4_B_CSP_7_g_CSP_8_V_CSP_
# sn2007sr__B_28_V_29_R_29_I_28__LOSS_gane
# sn2007sr__B_47_V_32_r_prime_33_i_prime_3
# sn2007sr__J_30_H_32_K_32__CfAIR2_friedma
# sn2007sr__u_CSP_15_B_CSP_29_g_CSP_29_V_C
# sn2007st__u_CSP_12_B_CSP_11_g_CSP_13_V_C
# sn2007ux__B_5_V_7_R_6_I_6__LOSS_ganeshal
# sn2007ux__B_22_V_23_r_prime_24_i_prime_2
# sn2007ux__u_CSP_7_B_CSP_17_g_CSP_17_V_CS
# sn2008af__B_11_V_10_r_prime_11_i_prime_1
# sn2008af__J_23_H_31_K_21__CfAIR2_friedma
# sn2008ar__B_15_V_19_R_17_I_15__LOSS_gane
# sn2008ar__B_24_V_24_r_prime_28_i_prime_2
# sn2008ar__u_CSP_8_B_CSP_18_g_CSP_18_V_CS
# sn2008bc__u_CSP_29_B_CSP_30_g_CSP_22_V_C
# sn2008bf__B_20_V_22_R_20_I_17__LOSS_gane
# sn2008bf__U_13_B_16_V_16_r_prime_18_i_pr
# sn2008bf__u_CSP_20_B_CSP_27_g_CSP_27_V_C
# sn2008bq__u_CSP_15_B_CSP_16_g_CSP_17_V_C
# sn2008bz__U_5_B_8_V_11_r_prime_12_i_prim
# sn2008bz__u_CSP_7_B_CSP_12_g_CSP_14_V_CS
# sn2008C__B_8_V_9_R_10_I_10__LOSS_ganesha
# sn2008C__B_19_V_19_r_prime_19_i_prime_20
# sn2008C__J_8_H_4_K_12__CfAIR2_friedman15
# sn2008C__u_CSP_6_B_CSP_12_g_CSP_17_V_CSP
# sn2008cc__u_CSP_21_B_CSP_20_g_CSP_19_V_C
# sn2008cf__U_3_B_7_V_8_r_prime_8_i_prime_
# sn2008cf__u_CSP_6_B_CSP_13_g_CSP_13_V_CS
# sn2008ff__u_CSP_17_B_CSP_23_g_CSP_23_V_C
# sn2008fl__u_CSP_20_B_CSP_23_g_CSP_23_V_C
# sn2008fp__u_CSP_27_B_CSP_29_g_CSP_29_V_C
# sn2008fr__J_5_H_6_K_6__CfAIR2_friedman15
# sn2008fr__U_17_B_19_V_21_r_prime_19_i_pr
# sn2008fr__u_CSP_8_B_CSP_20_g_CSP_19_V_CS
# sn2008fu__u_CSP_3_B_CSP_8_g_CSP_14_V_CSP
# sn2008fv__B_10_V_10_R_9_I_9_J_15_H_12_K_
# sn2008fv__J_3_H_3_K_3__CfAIR2_friedman15
# sn2008fw__u_CSP_21_B_CSP_23_g_CSP_24_V_C
# sn2008gb__J_19_H_14_K_12__CfAIR2_friedma
# sn2008gb__U_5_B_14_V_15_r_prime_14_i_pri
# sn2008gg__u_CSP_18_B_CSP_26_g_CSP_26_V_C
# sn2008gl__B_13_V_13_r_prime_13_i_prime_1
# sn2008gl__J_9_H_12_K_10__CfAIR2_friedman
# sn2008gl__u_CSP_16_B_CSP_19_g_CSP_22_V_C
# sn2008go__u_CSP_6_B_CSP_6_g_CSP_6_V_CSP_
# sn2008gp__u_CSP_14_B_CSP_21_g_CSP_17_V_C
# sn2008hj__U_2_B_4_V_4_r_prime_4_i_prime_
# sn2008hj__u_CSP_14_B_CSP_16_g_CSP_16_V_C
# sn2008hm__J_26_H_22_K_23__CfAIR2_friedma
# sn2008hm__U_13_B_17_V_23_r_prime_21_i_pr
# sn2008hs__J_20_H_21_K_17__CfAIR2_friedma
# sn2008hs__U_2_B_15_V_20_r_prime_20_i_pri
# sn2008hu__u_CSP_7_B_CSP_12_g_CSP_12_V_CS
# sn2008hv__B_31_V_36_r_prime_37_i_prime_3
# sn2008hv__J_26_H_29_K_24__CfAIR2_friedma
# sn2008hv__u_CSP_21_B_CSP_24_g_CSP_24_V_C
# sn2008ia__u_CSP_15_B_CSP_18_g_CSP_13_V_C
# sn2008O__u_CSP_6_B_CSP_18_g_CSP_14_V_CSP
# sn2008R__u_CSP_10_B_CSP_10_g_CSP_11_V_CS
# sn2008Z__B_7_V_7_R_7_I_7__LOSS_ganeshali
# sn2008Z__J_45_H_44_K_32__CfAIR2_friedman
# sn2008Z__U_12_B_24_V_25_r_prime_24_i_pri
# sn2009aa__u_CSP_16_B_CSP_22_g_CSP_22_V_C
# sn2009ab__u_CSP_10_B_CSP_10_g_CSP_10_V_C
# sn2009ad__J_27_H_20_K_19__CfAIR2_friedma
# sn2009ad__u_CSP_12_B_CSP_12_g_CSP_12_V_C
# sn2009ad__u_prime_10_B_18_V_19_r_prime_1
# sn2009ag__u_CSP_19_B_CSP_19_g_CSP_19_V_C
# sn2009al__J_22_H_22_K_19__CfAIR2_friedma
# sn2009al__u_CSP_13_B_CSP_15_g_CSP_15_V_C
# sn2009al__u_prime_3_B_20_V_20_r_prime_20
# sn2009an__J_31_H_29_K_22__CfAIR2_friedma
# sn2009an__u_prime_4_B_20_V_21_r_prime_20
# sn2009bv__B_18_V_18_r_prime_15_i_prime_1
# sn2009bv__J_13_H_13_K_8__CfAIR2_friedman
# sn2009cz__u_CSP_10_B_CSP_10_g_CSP_10_V_C
# sn2009D__B_15_V_18_r_prime_17_i_prime_18
# sn2009D__J_27_H_24_K_19__CfAIR2_friedman
# sn2009D__u_CSP_20_B_CSP_21_g_CSP_21_V_CS
# sn2009do__J_14_H_9_K_5__CfAIR2_friedman1
# sn2009do__u_prime_3_B_15_V_18_r_prime_18
# sn2009ds__B_8_V_12_r_prime_13_i_prime_12
# sn2009ds__J_6_H_6_K_3__CfAIR2_friedman15
# sn2009ds__u_CSP_11_B_CSP_11_g_CSP_11_V_C
# sn2009fv__B_7_V_6_r_prime_6_i_prime_5__C
# sn2009fv__J_6_H_5_K_3__CfAIR2_friedman15
# sn2009I__u_CSP_3_B_CSP_5_g_CSP_5_V_CSP_5
# sn2009ig__J_11_H_9_K_7__CfAIR2_friedman1
# sn2009ig__u_prime_18_B_26_V_26_r_prime_2
# sn2009jr__B_16_V_16_r_prime_15_i_prime_1
# sn2009jr__J_11_H_14_K_11__CfAIR2_friedma
# sn2009kk__B_18_V_19_r_prime_19_i_prime_1
# sn2009kk__J_17_H_17_K_16__CfAIR2_friedma
# sn2009kq__J_10_H_11_K_11__CfAIR2_friedma
# sn2009kq__u_prime_14_B_19_V_21_r_prime_2
# sn2009le__J_9_H_7_K_8__CfAIR2_friedman15
# sn2009le__u_CSP_9_B_CSP_9_g_CSP_9_V_CSP_
# sn2009le__u_prime_6_B_8_V_7_r_prime_4_i_
# sn2009lf__B_11_V_16_r_prime_16_i_prime_1
# sn2009lf__J_18_H_16_K_7__CfAIR2_friedman
# sn2009na__J_11_H_10_K_8__CfAIR2_friedman
# sn2009na__u_prime_3_B_14_V_15_r_prime_13
# sn2009P__u_CSP_10_B_CSP_15_g_CSP_14_V_CS
# sn2009Y__J_11_H_15_K_3__CfAIR2_friedman1
# sn2009Y__u_CSP_29_B_CSP_30_g_CSP_27_V_CS
# sn2009Y__u_prime_13_B_21_V_24_r_prime_25
# sn2010ag__J_15_H_15_K_9__CfAIR2_friedman
# sn2010ag__u_prime_3_B_13_V_17_r_prime_16
# sn2010ai__B_16_V_22_r_prime_21_i_prime_2
# sn2010ai__J_22_H_17_K_17__CfAIR2_friedma
# sn2010dw__B_7_V_8_r_prime_8_i_prime_8__C
# sn2010dw__J_6_H_6_K_4__CfAIR2_friedman15
# sn2010gn__B_4_V_4_r_prime_5_i_prime_4__C
# sn2010gn__J_3_H_3_K_2__CfAIR2_friedman15
# sn2010iw__B_23_V_23_r_prime_24_i_prime_2
# sn2010iw__J_18_H_18_K_13__CfAIR2_friedma
# sn2010ju__B_14_V_15_r_prime_16_i_prime_1
# sn2010ju__J_21_H_20_K_19__CfAIR2_friedma
# sn2010kg__B_23_V_23_r_prime_23_i_prime_2
# sn2010kg__J_25_H_27_K_12__CfAIR2_friedma
# sn2010Y__J_15_H_10_K_12__CfAIR2_friedman
# sn2010Y__u_prime_1_B_21_V_23_r_prime_24_
# sn2011ae__B_8_V_10_r_prime_10_i_prime_10
# sn2011ae__J_32_H_32_K_26__CfAIR2_friedma
# sn2011ao__B_16_V_36_r_prime_39_i_prime_3
# sn2011ao__J_28_H_29_K_16__CfAIR2_friedma
# sn2011B__B_30_V_31_r_prime_36_i_prime_37
# sn2011B__J_46_H_43_K_37__CfAIR2_friedman
# sn2011by__B_38_V_23_r_prime_31_i_prime_3
# sn2011by__J_28_H_27_K_13__CfAIR2_friedma
# sn2011df__B_15_V_15_r_prime_15_i_prime_1
# sn2011df__J_24_H_25_K_11__CfAIR2_friedma
# sn2011fe__B_40_V_46_r_prime_45_i_prime_4
# sn2011fe__J_31_H_35_K_31__WIYN_matheson1
# sn2011fe__U_94_B_116_V_117_R_115_I_116__
# sn2011K__B_4_V_7_r_prime_7_i_prime_8__Cf
# sn2011K__J_16_H_16_K_8__CfAIR2_friedman1
# sn2012cg__u_prime_19_B_28_V_30_r_prime_3
# sn2014J__U_17_B_18_V_20_R_20_I_19_J_24_H
# snf20080514-002__B_18_V_16_R_17_I_16__LO
# snf20080514-002__J_9_H_9_K_8__CfAIR2_fri
# snf20080522-000__B_9_V_12_r_prime_15_i_p
# snf20080522-000__J_4_H_3_K_1__CfAIR2_fri
# snf20080522-011__B_16_V_18_r_prime_17_i_
# snf20080522-011__J_8_H_9_K_2__CfAIR2_fri
#
# # All 341 LCs converted smoothly

# %%
snana_file.close();snana_file.close();snana_file.close();

# %% [markdown]
# ----
