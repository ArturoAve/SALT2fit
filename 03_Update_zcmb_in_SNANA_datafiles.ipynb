# %% [markdown]
# # Code to replace the (zcmb, zhelio) values to the updated values in Andy's compilation in the SNANA photometry data files
#
# - The output files will be saved in a folder called updated_zcmb

# %%
# User

# Type of sample. lowz = low-z sample of SNe Ia
# ps1 = panstarrs, des = DES. This definition is simply to include 
# or not the prefix 'sn' in the name of the SNe when defining the
# names to be used as entries in the dictionary in the second loop
# of the main loop. 
# The lowz sample needs the sufix 'sn' while ps1 and des don't.
sampletype = 'lowz'    # (lowz, ps1, des)
 
zcmb_update = True  # Update zcmb?
zhelio_update = True  # Update zhelio?


NotebookName = '02_Update_zcmb_in_SNANA_datafiles.ipynb'

#-----------------------------------------------

#     LOW-Z

FoldersList = [
"CFA3_KEPLERCAM",
"CFA4",
"CSPDR2",
"JLA2014_CSP",
"JLA2014_LOWZ_LANDOLT",
"LOWZ_CFA3",
"LOWZ_FromAndyFriedman",
"LOWZ_JRK07",
"PS1s_CFA3_KEPLERCAM_RS14",
"PS1s_CFA4_p1_RS14",
"PS1s_CFA4_p2_RS14",
"PS1s_CSPDR2_V_RS14",
"SNLS3year_CFA3_KEPLERCAM",
"SNLS3year_JRK07" ]


dirSnanaFolders = '/Users/arturo/Dropbox/Research/\
SoftwareResearch/SNANA/Odyssey/home_snana/lowz/2_AndySampleOnly/'

#-----------------------------------------------
#     RAISIN
""" 
# FolderSample = 'Data/'
FolderSample = ''

FoldersList = []

# dirSnanaFolders = '/Users/arturo/Dropbox/Research/Articulos/12_RAISINs/\
# Data/RAISIN_2/Data/DES/2017_11_21/Photometry/fit_SomeLinesCommented_ok/'

dirSnanaFolders = '/Users/arturo/Dropbox/Research/Articulos/12_RAISINs/Data/\
RAISIN_2/Data/DES/2017_11_21/Photometry/fit_SomeLinesCommented_ok/\
version_02/Data/1_zcmb_no_updated/'

"""

#--------------------------------------------

cc = 299792.458  # Speed of light (km/s)

# %% [markdown]
# --------

# %% [markdown]
# # Automatic

# %% [markdown]
# #### Function to identify string or number

# %%
# Function to identify if a string is an integer number or a letter.
# This will be used in the dictionary construction to properly read some SN names.

def is_number(s):
    try:
        int(s)
        return True
    except ValueError:
        return False

# Tests
print is_number('5'), is_number('e')
# True False
# Out:
# True False

# %%
# Get the current date and time
import datetime 

# Read the time and date now
now = datetime.datetime.now()

# %% [markdown]
# #### Get the name of this ipython notebook
# To print it in the output text files as reference.

# %%
# %%javascript
# var kernel = IPython.notebook.kernel;
# var thename = window.document.getElementById("notebook_name").innerHTML;
# var command = "NotebookName = " + "'"+thename+".ipynb"+"'";
# kernel.execute(command);

# %%
print '#', (NotebookName)

# Update_zcmb_in_SNANA_datafiles_v1_0.ipynb
# Out:
# # 02_Update_zcmb_in_SNANA_datafiles.ipynb

# %% [markdown]
# -----

# %% [markdown]
# ### Metadata LOW-Z SAMPLE
#
# I don't need to run these cells if I'm updating the RAISINs SNANA files

# %%
import numpy as np

DirMetadata = '/Users/arturo/Dropbox/Research/SoftwareResearch/\
Snoopy/AndyLCComp_2018_02/'

# Reading the metadata file
infoSNe_data = np.genfromtxt(DirMetadata+
                             'carrick_Flow_corrections_snnames_v1.txt',
                            dtype=['S17', float,float, 'S40',float,float,
                                   float,float,float,float,'S16', int ])

# Create a dictionary: 
# {snname: ra, dec, zhelio, e_zhel, zcmb, e_zcmb, zcmbFlow, e_zcmbFlow, code}

infoSNe_dict = {infoSNe_data['f0'][i]: np.array( [ infoSNe_data['f1'][i],
                infoSNe_data['f2'][i], 
                infoSNe_data['f4'][i]/cc, infoSNe_data['f5'][i]/cc,
                infoSNe_data['f6'][i]/cc, infoSNe_data['f7'][i]/cc,
                infoSNe_data['f8'][i]/cc, infoSNe_data['f9'][i]/cc,
                infoSNe_data['f11'][i]] )
                for i in range(len(infoSNe_data)) } 

print infoSNe_dict['sn1991T']
# [  1.88542500e+02   2.66556000e+00   5.79067269e-03   3.33564095e-06
#    3.19220839e-03   2.00138457e-05   6.60456908e-03   5.00346143e-04
#    2.00000000e+00]
# Out:
# [1.88542500e+02 2.66556000e+00 5.79067269e-03 3.33564095e-06
#  3.19220839e-03 2.00138457e-05 9.20636903e-04 5.00346143e-04
#  2.00000000e+00]

# %%
""" 
# (z_helio, error_z_helio)
# From WoodVasey & Andy Friedman metadata file.

DirMetadata = '/Users/arturo/Dropbox/Research/SoftwareResearch/Snoopy/AndyLCComp/MyNotesAbout/'

InfoSN_zHelio = np.genfromtxt(DirMetadata+'WoodVasey_Andy/WoodVasey_AndyFriedman_zCMB_2017_08_11_Converted_.txt',
                            usecols=(0,1,2), dtype=['S24', float, float])

# Create a dictionary: 
InfoSN_zHelio_dict ={}

for i in range(len(InfoSN_zHelio)):
    snname_int1 = InfoSN_zHelio[i][0]
    zHelio_int1 = InfoSN_zHelio[i][1]/cc
    err_zHelio_int1 = InfoSN_zHelio[i][2]/cc
    
    InfoSN_zHelio_dict[snname_int1] = [ zHelio_int1, err_zHelio_int1  ]
    
InfoSN_zHelio_dict['sn2006D']
# [0.0085258982732647672, 1.6678204759907602e-05]
"""
0
# Out:
# 0

# %%
"""
# (z_helio, error_z_helio, z_CMB, error_z_CMB) 
# From WoodVasey & Andy Friedman metadata file for the SPECIAL CASES

InfoSN_zCMB_Special = np.genfromtxt(DirMetadata+'WoodVasey_Andy/WoodVasey_AndyFriedman_zCMB_2017_08_11_SpecialCases_Converted_Ho70.txt',
                            usecols=(0,1,2, 14, 15), 
                            dtype=['S10', float, float, float, float])

# Create a dictionary: 
InfoSN_zCMB_Special_dict ={}

for i in range(len(InfoSN_zCMB_Special)):
    snname_int2 = InfoSN_zCMB_Special[i][0]
    zHelio_int2 = InfoSN_zCMB_Special[i][1]/cc
    err_zHelio_int2 = InfoSN_zCMB_Special[i][2]/cc
    zCMB_int2 = InfoSN_zCMB_Special[i][3]/cc
    err_zCMB_int2 = InfoSN_zCMB_Special[i][4]/cc
    
    InfoSN_zCMB_Special_dict[snname_int2] = [ zHelio_int2, err_zHelio_int2, 
                                              zCMB_int2, err_zCMB_int2  ]
    
InfoSN_zCMB_Special_dict['sn1999cl']
# [0.0076085970114698484,
# 1.0006922855944561e-05,
# 0.0031922083910463153,
# 2.0013845711889123e-05]
"""
0
# Out:
# 0

# %%
"""
# Using Michael Foley flow-corrected z_CMB + Cepheid distances + special cases
# compiled by Andy Friedman

InfoSN_zCMB_MFoley = np.genfromtxt(DirMetadata+'zCMB_FlowCorrected_MichaelFoley_original.txt',
                            usecols=(0, 1, 2, 5), dtype=['S18', float, float, float])

# Create a final dictionary: (snname: zhelio, err_zhelio, zcmb, err_zcmb, RA, DEC)
InfoSN_dict ={}

for i in range(len(InfoSN_zCMB_MFoley)):
    snname_int3     = InfoSN_zCMB_MFoley[i][0]
    zHelio_int3     = InfoSN_zHelio_dict[snname_int3][0]
    err_zHelio_int3 = InfoSN_zHelio_dict[snname_int3][1]
    RA_int  = InfoSN_zCMB_MFoley[i][1]
    DEC_int = InfoSN_zCMB_MFoley[i][2]
    
    
    #---- Define z_CMB and err_z_CMB ------
    
    if snname_int3 in list(InfoSN_zCMB_Special['f0']): # Special cases
        zCMB_int3 = InfoSN_zCMB_Special_dict[snname_int3][2]
        err_zCMB_int3 = InfoSN_zCMB_Special_dict[snname_int3][3]
    else: # Michael Foley's zcmb values
        zCMB_int3 = InfoSN_zCMB_MFoley[i][3]
        err_zCMB_int3 = 150/cc
    
    InfoSN_dict[snname_int3] = [ zHelio_int3, err_zHelio_int3, 
                                 zCMB_int3, err_zCMB_int3, RA_int, DEC_int ]
    
InfoSN_dict['sn1998bu']
# [0.0029920699339274241,
# 1.3342563807926082e-05,
# 0.0021141927350000001,
# 0.0005003461427972281,
# 161.69179,
# 11.83531]
"""
0
# Out:
# 0

# %% [markdown]
# -----

# %% [markdown]
# ### Metadata RAISINs
#
# Don't need to run these cells if I'm updating the LOW-Z SNANA files.

# %%
import numpy as np

# Metadata file

""" 
DirMetadata = '/Users/arturo/Dropbox/Research/Articulos/12_RAISINs/\
Metadata/useful_but_tmp/'

InfoSN_z = np.genfromtxt(DirMetadata+'table_zcmb_EBVmw_.txt',
                            dtype=['S15', float, float, float,
                                  float, float, float])
# Create a dictionary: 
InfoSN_z_dict ={}

for i in range(len(InfoSN_z)):
    snname_int1 = InfoSN_z[i][0]
    zHelio_int1 = InfoSN_z[i][1]
    e_zhelio_int1 = 0 # It is just a placeholder for now
    zcmb_int1 = InfoSN_z[i][4]
    e_zcmb_int1 = 0 # It is just a placeholder for now
    ebv_int1   = InfoSN_z[i][5]
    e_ebv_int1 = InfoSN_z[i][6]
    
    InfoSN_z_dict[snname_int1] = [ zHelio_int1, e_zhelio_int1,
                                   zcmb_int1,   e_zcmb_int1,
                                   ebv_int1,    e_ebv_int1]
    
InfoSN_z_dict['DES15C1nhv']
# [0.42047000000000001,
#  0,
#  0.42011100000000001,
#  0,
#  0.0091999999999999998,
#  0.00020000000000000001]

"""
0
# Out:
# 0

# %% [markdown]
# -----

# %% [markdown]
# # Read/replace zcmb, zhelio in SNANA photometry datafile

# %% [markdown]
# ### Main loop

# %%
# Read all the photometry file names in a given sample folder:
import os # To use command line like instructions
import glob # To read the files in my directory
# Read the time and date right now
now = datetime.datetime.now()

# Create a log file:
log_file = open(dirSnanaFolders+'Log_Updated_zcmb_files.log','w')

log_file.write("# SNANA file with updated zCMB (written in REDSHIFT_FINAL) based \n\
# on Michael Foley + Cepheid distances + special cases compiled by Andy Friedman. \n")

text_line = '#'+'-'*60+'\n'

log_file.write(text_line)
log_file.write('# Data table created by: Arturo Avelino \n')
text_01 = now.strftime("%Y-%m-%d (yyyy-mm-dd); %H:%M hrs.")
log_file.write('# On date: %s \n'%text_01)
log_file.write('# Script used: %s \n'%NotebookName)
log_file.write(text_line)
            
#------------------------------------------------

# Reset
countSN = 0 # Count number of SNe with updated values
countNoAndy = 0 # SNe that are NOT in Andy's sample
FolderSample = ''

# Loop over folder samples
for i in range(len(FoldersList)):
    
    FolderSample = FoldersList[i]
    print "#-------- %s ---------"%FolderSample
    
    # Change the working directory where the data files are located
    os.chdir(dirSnanaFolders+FolderSample+'/data/')

    #--- Reading the data files in the folder 
    list_SNe = glob.glob('*.DAT')
    if len(list_SNe) == 0: list_SNe = glob.glob('*.dat')
        
    # Create the folder where the output will be saved
    #- Force the creation of the directory to save the outputs.
    #- "If the subdirectory does not exist then create it"
    DirSaveOutput = dirSnanaFolders+FolderSample+'/updated_zcmb/'
    import os # To use command line like instructions
    if not os.path.exists(DirSaveOutput): os.makedirs(DirSaveOutput)
        
    # Create the ".LIST" text file for this folder sample.
    LIST_textfile = open(DirSaveOutput+FolderSample+'.LIST', 'w')
    for file2 in list_SNe:
        LIST_textfile.write("AndySampleOnly/%s/%s\n"%(FolderSample,file2))
    LIST_textfile.close()
    
    IGNORE_textfile = open(DirSaveOutput+FolderSample+'.IGNORE', 'w')
    IGNORE_textfile.write("\n"); IGNORE_textfile.close()
    
    README_textfile = open(DirSaveOutput+FolderSample+'.README', 'w')
    README_textfile.write("zCMB, zHELIO updated from Andy Friedman compilation\n"); 
    README_textfile.close()
    
    #-----------------------------------
    
    # Reset
    LIST_list = [] 
    
    # Loop 0: over all the SNANA files in a given folder sample.
    for file in list_SNe: 

        snanafile = file

        # resetting this variable first.
        snname = ''
        snname_int1 = ''
        snname_int2 = ''

        # Loop over each line of a given SNANA file 
        for line_1 in open(dirSnanaFolders+FolderSample+'/data/'+snanafile):

            # Find the line_1 with the SN name and define a temporal variable 
            if line_1[:5] == 'SNID:': 
                snname_int1 = line_1[6:]

                # Remove the blank spaces before and after the temporal SN name:
                for ss in snname_int1:  
                    if ss != ' ': snname_int2 = snname_int2 + ss

                if   sampletype == 'lowz' : snname = 'sn'+snname_int2[:-1]
                elif sampletype == 'ps1' or sampletype == 'des': 
                    snname = snname_int2[:-1]

                # print snname

        #-----------------------------------

        if sampletype == 'lowz':

            # Loop 2: # Write down the SNANA file but with the 
            # updated (z_CMB, zhelio)

            # Check if this SN is in the metadata file where I have 
            # updated (z_CMB, zhelio) values for certain SNe.
            if snname in infoSNe_data['f0']:

                log_file.write('   %s \n'%snanafile)
                print '   %s'%snanafile

                # Open the new text file:
                newSNANAtext = open(DirSaveOutput+snanafile, 'w')

                newSNANAtext.write("# SNANA file with updated zCMB (written in REDSHIFT_FINAL and \
REDSHIFT_CMB) based on \n# Carrick flow model compiled by Andy Friedman. \n")
                # newSNANAtext.write(text_line)
                newSNANAtext.write('# Data table created by: Arturo Avelino \n')
                # text_01 = now.strftime("%Y-%m-%d (yyyy-mm-dd); %H:%M hrs.")
                # newSNANAtext.write('# On date: %s \n'%text_01)
                # newSNANAtext.write('# Script used: %s \n'%NotebookName)
                newSNANAtext.write(text_line)

                # Loop over each line of a given SNANA file 
                for line_2 in open(dirSnanaFolders+FolderSample+'/data/'+snanafile):

                    # Find the line_2 with 'REDSHIFT_FINAL' and replace the value of zcmb.
                    if line_2[:14] == 'REDSHIFT_FINAL':

                        if infoSNe_dict[snname][8] == 0:
                            zcmb_new     = infoSNe_dict[snname][6] 
                            err_zcmb_new = infoSNe_dict[snname][7] 
                        else:
                            zcmb_new     = infoSNe_dict[snname][4] 
                            err_zcmb_new = infoSNe_dict[snname][5] 

                        # Write the updated zcmb line_2 to the text file
                        text_int1 = 'REDSHIFT_FINAL: %1.5f +- %1.6f (CMB)'%(zcmb_new, err_zcmb_new)
                        newSNANAtext.write(text_int1+'\n')

                        log_file.write('old: '+ line_2)
                        log_file.write('new: '+ text_int1 + '\n')
                        log_file.write(' \n')
                        print 'old:', line_2, 'new:', text_int1


                    elif line_2[:12] == 'REDSHIFT_CMB' and zcmb_update:

                        if infoSNe_dict[snname][8] == 0:
                            zcmb_new     = infoSNe_dict[snname][6] 
                            err_zcmb_new = infoSNe_dict[snname][7] 
                        else:
                            zcmb_new     = infoSNe_dict[snname][4] 
                            err_zcmb_new = infoSNe_dict[snname][5] 

                        # Write the updated zcmb line_2 to the text file
                        text_int1 = 'REDSHIFT_CMB: %1.5f +- %1.6f (CMB)'%(zcmb_new, err_zcmb_new)
                        newSNANAtext.write(text_int1+'\n')

                        log_file.write('old: '+ line_2)
                        log_file.write('new: '+ text_int1 + '\n')
                        log_file.write(' \n')
                        print 'old:', line_2, 'new:', text_int1


                    elif line_2[:14] == 'REDSHIFT_HELIO' and zhelio_update:

                        zhel_new     = infoSNe_dict[snname][2] 
                        err_zhel_new = infoSNe_dict[snname][3] 

                        # Write the updated zhelio line_2 to the text file
                        text_int1 = 'REDSHIFT_HELIO: %1.5f +- %1.6f (HEL)'%(zhel_new, err_zhel_new)
                        newSNANAtext.write(text_int1+'\n')

                        log_file.write('old: '+ line_2)
                        log_file.write('new: '+ text_int1 + '\n')
                        log_file.write(' \n')
                        print 'old:', line_2, 'new:', text_int1

                    # Write all the other "line_2" to the text file
                    else: newSNANAtext.write(line_2)

                newSNANAtext.close()
                countSN = countSN + 1

            else:  
                text_log_02 = '   %s: No in Andy s sample. \n'%snanafile
                log_file.write(text_log_02)
                log_file.write(' \n')
                print text_log_02
                countNoAndy = countNoAndy + 1

        #-----------------------------------

        elif sampletype == 'ps1' or sampletype == 'des': 

            # Loop 2: # Write down the SNANA file but with the 
            # updated (z_CMB, zhelio)

            # Check if this SN is in the metadata file where I have 
            # updated (z_CMB, zhelio) values for certain SNe.
            if snname in InfoSN_z['f0']:

                log_file.write('   %s \n'%snanafile)
                print '   %s'%snanafile

                # Open the new text file:
                newSNANAtext = open(DirSaveOutput+snanafile, 'w')

                newSNANAtext.write("# SNANA file with updated zhelio and/or zCMB \
(written in REDSHIFT_FINAL). \n")
                newSNANAtext.write('# Data table created by: Arturo Avelino \n')
                text_01 = now.strftime("%Y-%m-%d (yyyy-mm-dd); %H:%M hrs.")
                newSNANAtext.write('# On date: %s \n'%text_01)
                newSNANAtext.write('# Script used: %s \n'%NotebookName)
                text_line = '#'+'-'*60+'\n'
                newSNANAtext.write(text_line)

                zhel_new     = InfoSN_z_dict[snname][0] 
                err_zhel_new = InfoSN_z_dict[snname][1]
                zcmb_new     = InfoSN_z_dict[snname][2] 
                err_zcmb_new = InfoSN_z_dict[snname][3] 

                # Loop over each line of a given SNANA file   
                for line_2 in open(dirSnanaFolders+FolderSample+'/'+snanafile):

                    # Find the line_2 with 'REDSHIFT_xxx' and replace the value of zxxx.
                    # if  zcmb_update == True:
                    if line_2[:15] == 'REDSHIFT_FINAL:':
                        text_int0 = line_2[25:]
                        text_int1 = 'REDSHIFT_FINAL:  %1.5f  %s'%(zcmb_new, text_int0)
                        text_log1 = 'old: '+ line_2
                        text_log2 = 'new: '+ text_int1
                        log_file.write(text_log1); log_file.write(text_log2); 
                        print text_log1, text_log2

                    elif line_2[:15] == 'REDSHIFT_HELIO:':
                        text_int0 = line_2[25:]
                        text_int1 = 'REDSHIFT_HELIO:  %1.5f  %s'%(zhel_new, text_int0)
                        text_log1 = 'old: '+ line_2
                        text_log2 = 'new: '+ text_int1
                        log_file.write(text_log1); log_file.write(text_log2);
                        print text_log1, text_log2

                    # Write all the other "line_2's" lines to the text file
                    else: text_int1 = line_2

                    # Write the updated zcmb line_2 to the text file
                    newSNANAtext.write(text_int1)

                newSNANAtext.close()
                countSN = countSN + 1

            else:  
                text_log_02 = '   %s: No in Andy s sample. \n'%snanafile
                log_file.write(text_log_02)
                log_file.write(' \n')
                print text_log_02
                countNoAndy = countNoAndy + 1

        #-----------------------------------

    text_10 = '%s SNe were updated their zcmb values peacefully :) \n'%countSN
    text_11 = "%s SNe are not in the metadata file. \n"%countNoAndy

    log_file.write(text_line); log_file.write(text_10); log_file.write(text_11)
    print
    print text_10, text_11

#-----------------------------------
log_file.close()
# Out:
# #-------- CFA3_KEPLERCAM ---------
#    CFA3_KEPLERCAM_2005cf.DAT
# old: REDSHIFT_HELIO:  0.0065 +- 0.0001  (Helio frame)
# new: REDSHIFT_HELIO: 0.00643 +- 0.000017 (HEL)
# old: REDSHIFT_CMB:    0.0070 +- 0.0001  (CMB frame)
# new: REDSHIFT_CMB: 0.00693 +- 0.000364 (CMB)
# old: REDSHIFT_FINAL:  0.0070 +- 0.0001  (CMB frame)
# new: REDSHIFT_FINAL: 0.00693 +- 0.000364 (CMB)
#    CFA3_KEPLERCAM_2006D.DAT
# old: REDSHIFT_HELIO:  0.0086 +- 0.0001  (Helio frame)
# new: REDSHIFT_HELIO: 0.00853 +- 0.000017 (HEL)
# old: REDSHIFT_CMB:    0.0098 +- 0.0001  (CMB frame)
# new: REDSHIFT_CMB: 0.00898 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL:  0.0098 +- 0.0001  (CMB frame)
# new: REDSHIFT_FINAL: 0.00898 +- 0.000500 (CMB)
#    CFA3_KEPLERCAM_2006lf.DAT
# old: REDSHIFT_HELIO:  0.0132 +- 0.0001  (Helio frame)
# new: REDSHIFT_HELIO: 0.01319 +- 0.000017 (HEL)
# old: REDSHIFT_CMB:    0.0130 +- 0.0001  (CMB frame)
# new: REDSHIFT_CMB: 0.01210 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL:  0.0130 +- 0.0001  (CMB frame)
# new: REDSHIFT_FINAL: 0.01210 +- 0.000500 (CMB)
#
# 3 SNe were updated their zcmb values peacefully :)
# 0 SNe are not in the metadata file.
#
# #-------- CFA4 ---------
#    CFA4_2008gb.dat
# old: REDSHIFT_HELIO:    0.037000000 +- 0.000100000
# new: REDSHIFT_HELIO: 0.03700 +- 0.000167 (HEL)
# old: REDSHIFT_FINAL:  0.036400000 +- 0.000100000 (CMB)
# new: REDSHIFT_FINAL: 0.03812 +- 0.000500 (CMB)
#    CFA4_2008hs.dat
# old: REDSHIFT_HELIO:    0.017300000 +- 0.000100000
# new: REDSHIFT_HELIO: 0.01737 +- 0.000070 (HEL)
# old: REDSHIFT_FINAL:  0.016600000 +- 0.000100000 (CMB)
# new: REDSHIFT_FINAL: 0.01886 +- 0.000043 (CMB)
#    CFA4_2009al.dat
# old: REDSHIFT_HELIO:    0.022100000 +- 0.000100000
# new: REDSHIFT_HELIO: 0.02211 +- 0.000080 (HEL)
# old: REDSHIFT_FINAL:  0.023300000 +- 0.000100000 (CMB)
# new: REDSHIFT_FINAL: 0.02337 +- 0.000500 (CMB)
#    CFA4_2009an.dat
# old: REDSHIFT_HELIO:    0.0092000000 +- 0.000100000
# new: REDSHIFT_HELIO: 0.00922 +- 0.000007 (HEL)
# old: REDSHIFT_FINAL:  0.0095000000 +- 0.000100000 (CMB)
# new: REDSHIFT_FINAL: 0.01070 +- 0.000500 (CMB)
#    CFA4_2009bv.dat
# old: REDSHIFT_HELIO:    0.036700000 +- 0.000100000
# new: REDSHIFT_HELIO: 0.03658 +- 0.000017 (HEL)
# old: REDSHIFT_FINAL:  0.037500000 +- 0.000100000 (CMB)
# new: REDSHIFT_FINAL: 0.03849 +- 0.000500 (CMB)
#    CFA4_2010ai.dat
# old: REDSHIFT_HELIO:    0.018400000 +- 0.000100000
# new: REDSHIFT_HELIO: 0.01837 +- 0.000123 (HEL)
# old: REDSHIFT_FINAL:  0.019300000 +- 0.000100000 (CMB)
# new: REDSHIFT_FINAL: 0.02390 +- 0.000180 (CMB)
#
# 9 SNe were updated their zcmb values peacefully :)
# 0 SNe are not in the metadata file.
#
# #-------- CSPDR2 ---------
#    CSPDR2_2004eo.dat
# old: REDSHIFT_HELIO:    0.015701 +- 0.000020
# new: REDSHIFT_HELIO: 0.01562 +- 0.000003 (HEL)
# old: REDSHIFT_FINAL:  0.014750 +- 0.000020 (CMB)
# new: REDSHIFT_FINAL: 0.01521 +- 0.000500 (CMB)
#    CSPDR2_2004ey.dat
# old: REDSHIFT_HELIO:    0.015800 +- 0.001000
# new: REDSHIFT_HELIO: 0.01584 +- 0.000003 (HEL)
# old: REDSHIFT_FINAL:  0.014600 +- 0.001000 (CMB)
# new: REDSHIFT_FINAL: 0.01540 +- 0.000500 (CMB)
#    CSPDR2_2005el.dat
# old: REDSHIFT_HELIO:    0.014910 +- 0.000017
# new: REDSHIFT_HELIO: 0.01491 +- 0.000017 (HEL)
# old: REDSHIFT_FINAL:  0.014894 +- 0.000017 (CMB)
# new: REDSHIFT_FINAL: 0.01526 +- 0.000500 (CMB)
#    CSPDR2_2005iq.dat
# old: REDSHIFT_HELIO:    0.034044 +- 0.000123
# new: REDSHIFT_HELIO: 0.03404 +- 0.000123 (HEL)
# old: REDSHIFT_FINAL:  0.032953 +- 0.000123 (CMB)
# new: REDSHIFT_FINAL: 0.03355 +- 0.000500 (CMB)
#    CSPDR2_2005kc.dat
# old: REDSHIFT_HELIO:    0.015120 +- 0.000017
# new: REDSHIFT_HELIO: 0.01509 +- 0.000003 (HEL)
# old: REDSHIFT_FINAL:  0.013900 +- 0.000017 (CMB)
# new: REDSHIFT_FINAL: 0.01449 +- 0.000500 (CMB)
#    CSPDR2_2005ki.dat
# old: REDSHIFT_HELIO:    0.019607 +- 0.000153
# new: REDSHIFT_HELIO: 0.01946 +- 0.000010 (HEL)
# old: REDSHIFT_FINAL:  0.020784 +- 0.000153 (CMB)
# new: REDSHIFT_FINAL: 0.02028 +- 0.000500 (CMB)
#    CSPDR2_2006ax.dat
# old: REDSHIFT_HELIO:    0.016738 +- 0.000023
# new: REDSHIFT_HELIO: 0.01672 +- 0.000020 (HEL)
# old: REDSHIFT_FINAL:  0.017969 +- 0.000023 (CMB)
# new: REDSHIFT_FINAL: 0.01797 +- 0.000500 (CMB)
#    CSPDR2_2006bh.dat
# old: REDSHIFT_HELIO:    0.010900 +- 0.001000
# new: REDSHIFT_HELIO: 0.01085 +- 0.000013 (HEL)
# old: REDSHIFT_FINAL:  0.010500 +- 0.001000 (CMB)
# new: REDSHIFT_FINAL: 0.01075 +- 0.000500 (CMB)
#    CSPDR2_2006bt.dat
# old: REDSHIFT_HELIO:    0.032156 +- 0.000233
# new: REDSHIFT_HELIO: 0.03208 +- 0.000007 (HEL)
# old: REDSHIFT_FINAL:  0.032479 +- 0.000233 (CMB)
# new: REDSHIFT_FINAL: 0.03072 +- 0.000500 (CMB)
#    CSPDR2_2006kf.dat
# old: REDSHIFT_FINAL:  0.020799 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01942 +- 0.000500 (CMB)
#    CSPDR2_2007A.dat
# old: REDSHIFT_FINAL:  0.016463 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01722 +- 0.000500 (CMB)
#    CSPDR2_2007af.dat
# old: REDSHIFT_FINAL:  0.006290 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.00556 +- 0.000177 (CMB)
#    CSPDR2_2007ai.dat
# old: REDSHIFT_FINAL:  0.031987 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.03274 +- 0.000500 (CMB)
#    CSPDR2_2007as.dat
# old: REDSHIFT_FINAL:  0.017896 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01836 +- 0.000500 (CMB)
#    CSPDR2_2007bc.dat
# old: REDSHIFT_HELIO:    0.020771 +- 0.000113
# new: REDSHIFT_HELIO: 0.02075 +- 0.000007 (HEL)
# old: REDSHIFT_FINAL:  0.021865 +- 0.000113 (CMB)
# new: REDSHIFT_FINAL: 0.02112 +- 0.000500 (CMB)
#    CSPDR2_2007bd.dat
# old: REDSHIFT_HELIO:    0.031018 +- 0.000217
# new: REDSHIFT_HELIO: 0.03044 +- 0.000100 (HEL)
# old: REDSHIFT_FINAL:  0.031959 +- 0.000217 (CMB)
# new: REDSHIFT_FINAL: 0.03108 +- 0.000500 (CMB)
#    CSPDR2_2007ca.dat
# old: REDSHIFT_FINAL:  0.015070 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01447 +- 0.000500 (CMB)
#    CSPDR2_2007jg.dat
# old: REDSHIFT_FINAL:  0.036577 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.03796 +- 0.000500 (CMB)
#    CSPDR2_2007le.dat
# old: REDSHIFT_FINAL:  0.005522 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.00647 +- 0.000500 (CMB)
#    CSPDR2_2008bc.dat
# old: REDSHIFT_FINAL:  0.015707 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01560 +- 0.000500 (CMB)
#    CSPDR2_2008gp.dat
# old: REDSHIFT_FINAL:  0.032824 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.03346 +- 0.000500 (CMB)
#    CSPDR2_2008hv.dat
# old: REDSHIFT_FINAL:  0.013581 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01396 +- 0.000500 (CMB)
#
# 31 SNe were updated their zcmb values peacefully :)
# 0 SNe are not in the metadata file.
#
# #-------- JLA2014_CSP ---------
#    JLA2014_CSP_2004ey.dat
# old: REDSHIFT_HELIO: 0.0158 +- 0.001    (HELIO)
# new: REDSHIFT_HELIO: 0.01584 +- 0.000003 (HEL)
# old: REDSHIFT_CMB: 0.0146 +- 0.001    (CMB)
# new: REDSHIFT_CMB: 0.01540 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0146 +- 0.001    (CMB)
# new: REDSHIFT_FINAL: 0.01540 +- 0.000500 (CMB)
#    JLA2014_CSP_2005iq.dat
# old: REDSHIFT_HELIO: 0.034044 +- 0.000123    (HELIO)
# new: REDSHIFT_HELIO: 0.03404 +- 0.000123 (HEL)
# old: REDSHIFT_CMB: 0.032953 +- 0.000123    (CMB)
# new: REDSHIFT_CMB: 0.03355 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.032953 +- 0.000123    (CMB)
# new: REDSHIFT_FINAL: 0.03355 +- 0.000500 (CMB)
#    JLA2014_CSP_2005kc.dat
# old: REDSHIFT_HELIO: 0.01512 +- 1.7e-05    (HELIO)
# new: REDSHIFT_HELIO: 0.01509 +- 0.000003 (HEL)
# old: REDSHIFT_CMB: 0.0139 +- 1.7e-05    (CMB)
# new: REDSHIFT_CMB: 0.01449 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0139 +- 1.7e-05    (CMB)
# new: REDSHIFT_FINAL: 0.01449 +- 0.000500 (CMB)
#    JLA2014_CSP_2005ki.dat
# old: REDSHIFT_HELIO: 0.019607 +- 0.000153    (HELIO)
# new: REDSHIFT_HELIO: 0.01946 +- 0.000010 (HEL)
# old: REDSHIFT_CMB: 0.020784 +- 0.000153    (CMB)
# new: REDSHIFT_CMB: 0.02028 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.020784 +- 0.000153    (CMB)
# new: REDSHIFT_FINAL: 0.02028 +- 0.000500 (CMB)
#    JLA2014_CSP_2006ax.dat
# old: REDSHIFT_HELIO: 0.016738 +- 2.3e-05    (HELIO)
# new: REDSHIFT_HELIO: 0.01672 +- 0.000020 (HEL)
# old: REDSHIFT_CMB: 0.017969 +- 2.3e-05    (CMB)
# new: REDSHIFT_CMB: 0.01797 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.017969 +- 2.3e-05    (CMB)
# new: REDSHIFT_FINAL: 0.01797 +- 0.000500 (CMB)
#    JLA2014_CSP_2006bh.dat
# old: REDSHIFT_HELIO: 0.0109 +- 0.001    (HELIO)
# new: REDSHIFT_HELIO: 0.01085 +- 0.000013 (HEL)
# old: REDSHIFT_CMB: 0.0105 +- 0.001    (CMB)
# new: REDSHIFT_CMB: 0.01075 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0105 +- 0.001    (CMB)
# new: REDSHIFT_FINAL: 0.01075 +- 0.000500 (CMB)
#
# 37 SNe were updated their zcmb values peacefully :)
# 0 SNe are not in the metadata file.
#
# #-------- JLA2014_LOWZ_LANDOLT ---------
#    JLA2014_lowzOther_2000ca.dat
# old: REDSHIFT_HELIO: 0.023616 +- 0.0002    (HELIO)
# new: REDSHIFT_HELIO: 0.02362 +- 0.000200 (HEL)
# old: REDSHIFT_CMB: 0.024525 +- 0.0002    (CMB)
# new: REDSHIFT_CMB: 0.02391 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.024525 +- 0.0002    (CMB)
# new: REDSHIFT_FINAL: 0.02391 +- 0.000500 (CMB)
#    JLA2014_lowzOther_2001ba.dat
# old: REDSHIFT_HELIO: 0.02942 +- 3e-05    (HELIO)
# new: REDSHIFT_HELIO: 0.02956 +- 0.000033 (HEL)
# old: REDSHIFT_CMB: 0.030529 +- 3e-05    (CMB)
# new: REDSHIFT_CMB: 0.03022 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.030529 +- 3e-05    (CMB)
# new: REDSHIFT_FINAL: 0.03022 +- 0.000500 (CMB)
#    JLA2014_lowzOther_2001bt.dat
# old: REDSHIFT_HELIO: 0.01464 +- 3.3e-05    (HELIO)
# new: REDSHIFT_HELIO: 0.01464 +- 0.000033 (HEL)
# old: REDSHIFT_CMB: 0.014448 +- 3.3e-05    (CMB)
# new: REDSHIFT_CMB: 0.01421 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.014448 +- 3.3e-05    (CMB)
# new: REDSHIFT_FINAL: 0.01421 +- 0.000500 (CMB)
#    JLA2014_lowzOther_2001cz.dat
# old: REDSHIFT_HELIO: 0.01538 +- 3e-05    (HELIO)
# new: REDSHIFT_HELIO: 0.01549 +- 0.000027 (HEL)
# old: REDSHIFT_CMB: 0.016346 +- 3e-05    (CMB)
# new: REDSHIFT_CMB: 0.01709 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.016346 +- 3e-05    (CMB)
# new: REDSHIFT_FINAL: 0.01709 +- 0.000500 (CMB)
#
# 41 SNe were updated their zcmb values peacefully :)
# 0 SNe are not in the metadata file.
#
# #-------- LOWZ_CFA3 ---------
#    LOWZ_CFA3_2005cf.dat
# old: REDSHIFT_HELIO: 0.006461 +- 0.000100 (Helio frame)
# new: REDSHIFT_HELIO: 0.00643 +- 0.000017 (HEL)
# old: REDSHIFT_CMB: 0.007045 +- 0.000100 (CMB frame)
# new: REDSHIFT_CMB: 0.00693 +- 0.000364 (CMB)
# old: REDSHIFT_FINAL: 0.007045 +- 0.000100 (CMB frame)
# new: REDSHIFT_FINAL: 0.00693 +- 0.000364 (CMB)
#    LOWZ_CFA3_2006D.dat
# old: REDSHIFT_HELIO: 0.008632 +- 0.000100 (Helio frame)
# new: REDSHIFT_HELIO: 0.00853 +- 0.000017 (HEL)
# old: REDSHIFT_CMB: 0.009754 +- 0.000100 (CMB frame)
# new: REDSHIFT_CMB: 0.00898 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.009754 +- 0.000100 (CMB frame)
# new: REDSHIFT_FINAL: 0.00898 +- 0.000500 (CMB)
#    LOWZ_CFA3_2006lf.dat
# old: REDSHIFT_HELIO: 0.013206 +- 0.000100 (Helio frame)
# new: REDSHIFT_HELIO: 0.01319 +- 0.000017 (HEL)
# old: REDSHIFT_CMB: 0.012972 +- 0.000100 (CMB frame)
# new: REDSHIFT_CMB: 0.01210 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.012972 +- 0.000100 (CMB frame)
# new: REDSHIFT_FINAL: 0.01210 +- 0.000500 (CMB)
#
# 44 SNe were updated their zcmb values peacefully :)
# 0 SNe are not in the metadata file.
#
# #-------- LOWZ_FromAndyFriedman ---------
#    sn2010kg_CfA_Wstd_27_5_snana.dat
# old: REDSHIFT_HELIO: 0.01663 +- 0.000007 (HEL)
# new: REDSHIFT_HELIO: 0.01663 +- 0.000007 (HEL)
# old: REDSHIFT_CMB: 0.01711 +- 0.000500 (CMB)
# new: REDSHIFT_CMB: 0.01711 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.01711 +- 0.000500 (CMB)
# new: REDSHIFT_FINAL: 0.01711 +- 0.000500 (CMB)
#    sn2011ao_CfA_Wstd_27_5_snana.dat
# old: REDSHIFT_HELIO: 0.01071 +- 0.000003 (HEL)
# new: REDSHIFT_HELIO: 0.01071 +- 0.000003 (HEL)
# old: REDSHIFT_CMB: 0.01198 +- 0.000500 (CMB)
# new: REDSHIFT_CMB: 0.01198 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.01198 +- 0.000500 (CMB)
# new: REDSHIFT_FINAL: 0.01198 +- 0.000500 (CMB)
#    sn2011B__CfA_Wstd_27_5_snana.dat
# old: REDSHIFT_HELIO: 0.00467 +- 0.000003 (HEL)
# new: REDSHIFT_HELIO: 0.00467 +- 0.000003 (HEL)
# old: REDSHIFT_CMB: 0.00557 +- 0.000500 (CMB)
# new: REDSHIFT_CMB: 0.00557 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.00557 +- 0.000500 (CMB)
# new: REDSHIFT_FINAL: 0.00557 +- 0.000500 (CMB)
#    sn2011by_CfA_Wstd_27_5_snana.dat
# old: REDSHIFT_HELIO: 0.00284 +- 0.000003 (HEL)
# new: REDSHIFT_HELIO: 0.00284 +- 0.000003 (HEL)
# old: REDSHIFT_CMB: 0.00507 +- 0.000203 (CMB)
# new: REDSHIFT_CMB: 0.00507 +- 0.000203 (CMB)
# old: REDSHIFT_FINAL: 0.00507 +- 0.000203 (CMB)
# new: REDSHIFT_FINAL: 0.00507 +- 0.000203 (CMB)
#    sn2011df_CfA_Wstd_27_5_snana.dat
# old: REDSHIFT_HELIO: 0.01455 +- 0.000020 (HEL)
# new: REDSHIFT_HELIO: 0.01455 +- 0.000020 (HEL)
# old: REDSHIFT_CMB: 0.01501 +- 0.000500 (CMB)
# new: REDSHIFT_CMB: 0.01501 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.01501 +- 0.000500 (CMB)
# new: REDSHIFT_FINAL: 0.01501 +- 0.000500 (CMB)
#
# 49 SNe were updated their zcmb values peacefully :)
# 0 SNe are not in the metadata file.
#
# #-------- LOWZ_JRK07 ---------
#    LOWZ_JRK07_1998bu.DAT
# old: REDSHIFT_FINAL:  0.0040 +- 0.0001  (CMB)
# new: REDSHIFT_FINAL: 0.00253 +- 0.000233 (CMB)
#    LOWZ_JRK07_1999ee.DAT
# old: REDSHIFT_FINAL:  0.0106 +- 0.0001  (CMB)
# new: REDSHIFT_FINAL: 0.01123 +- 0.000500 (CMB)
#    LOWZ_JRK07_1999ek.DAT
# old: REDSHIFT_FINAL:  0.0176 +- 0.0001  (CMB)
# new: REDSHIFT_FINAL: 0.01781 +- 0.000500 (CMB)
#    LOWZ_JRK07_2000E.DAT
# old: REDSHIFT_FINAL:  0.0042 +- 0.0001  (CMB)
# new: REDSHIFT_FINAL: 0.00562 +- 0.000500 (CMB)
#    LOWZ_JRK07_2001bt.DAT
# old: REDSHIFT_FINAL:  0.0144 +- 0.0001  (CMB)
# new: REDSHIFT_FINAL: 0.01421 +- 0.000500 (CMB)
#    LOWZ_JRK07_2001cz.DAT
# old: REDSHIFT_FINAL:  0.0163 +- 0.0001  (CMB)
# new: REDSHIFT_FINAL: 0.01709 +- 0.000500 (CMB)
#    LOWZ_JRK07_2001el.DAT
# old: REDSHIFT_FINAL:  0.0037 +- 0.0001  (CMB)
# new: REDSHIFT_FINAL: 0.00447 +- 0.000140 (CMB)
#
# 56 SNe were updated their zcmb values peacefully :)
# 0 SNe are not in the metadata file.
#
# #-------- PS1s_CFA3_KEPLERCAM_RS14 ---------
#    CFA3_KEPLERCAM_2005cf.DAT
# old: REDSHIFT_HELIO:  0.006482 +- 0.000500000  (Hel)
# new: REDSHIFT_HELIO: 0.00643 +- 0.000017 (HEL)
# old: REDSHIFT_CMB:  0.00706588353448 +- 0.000500000  (CMB)
# new: REDSHIFT_CMB: 0.00693 +- 0.000364 (CMB)
# old: REDSHIFT_FINAL: 0.00706588353448 +- 0.000500000  (CMB)
# new: REDSHIFT_FINAL: 0.00693 +- 0.000364 (CMB)
#    CFA3_KEPLERCAM_2006D.DAT
# old: REDSHIFT_HELIO:  0.008563 +- 0.000500000  (Hel)
# new: REDSHIFT_HELIO: 0.00853 +- 0.000017 (HEL)
# old: REDSHIFT_CMB:  0.00968369555787 +- 0.000500000  (CMB)
# new: REDSHIFT_CMB: 0.00898 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.00968369555787 +- 0.000500000  (CMB)
# new: REDSHIFT_FINAL: 0.00898 +- 0.000500 (CMB)
#    CFA3_KEPLERCAM_2006lf.DAT
# old: REDSHIFT_HELIO:  0.0126 +- 0.000500000  (Hel)
# new: REDSHIFT_HELIO: 0.01319 +- 0.000017 (HEL)
# old: REDSHIFT_CMB:  0.0123674158003 +- 0.000500000  (CMB)
# new: REDSHIFT_CMB: 0.01210 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0123674158003 +- 0.000500000  (CMB)
# new: REDSHIFT_FINAL: 0.01210 +- 0.000500 (CMB)
#    CFA3_KEPLERCAM_2008bf.DAT
# old: REDSHIFT_HELIO:  0.0253 +- 0.000500000  (Hel)
# new: REDSHIFT_HELIO: 0.02350 +- 0.000167 (HEL)
# old: REDSHIFT_CMB:  0.0263702384292 +- 0.000500000  (CMB)
# new: REDSHIFT_CMB: 0.02538 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0263702384292 +- 0.000500000  (CMB)
# new: REDSHIFT_FINAL: 0.02538 +- 0.000500 (CMB)
#
# 60 SNe were updated their zcmb values peacefully :)
# 0 SNe are not in the metadata file.
#
# #-------- PS1s_CFA4_p1_RS14 ---------
#    CFA4_p1_2008ar.dat
# old: REDSHIFT_HELIO:  0.02617 +- 0.000500000  (Hel)
# new: REDSHIFT_HELIO: 0.02617 +- 0.000010 (HEL)
# old: REDSHIFT_CMB:  0.0272874618608 +- 0.000500000  (CMB)
# new: REDSHIFT_CMB: 0.02895 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0272874618608 +- 0.000500000  (CMB)
# new: REDSHIFT_FINAL: 0.02895 +- 0.000500 (CMB)
#    CFA4_p1_2008gb.dat
# old: REDSHIFT_HELIO:  0.037 +- 0.000500000  (Hel)
# new: REDSHIFT_HELIO: 0.03700 +- 0.000167 (HEL)
# old: REDSHIFT_CMB:  0.0364274745006 +- 0.000500000  (CMB)
# new: REDSHIFT_CMB: 0.03812 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0364274745006 +- 0.000500000  (CMB)
# new: REDSHIFT_FINAL: 0.03812 +- 0.000500 (CMB)
#    CFA4_p1_2008hj.dat
# old: REDSHIFT_HELIO:  0.038639 +- 0.000500000  (Hel)
# new: REDSHIFT_HELIO: 0.03789 +- 0.000130 (HEL)
# old: REDSHIFT_CMB:  0.0374924347815 +- 0.000500000  (CMB)
# new: REDSHIFT_CMB: 0.03716 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0374924347815 +- 0.000500000  (CMB)
# new: REDSHIFT_FINAL: 0.03716 +- 0.000500 (CMB)
#    CFA4_p1_2008hs.dat
# old: REDSHIFT_HELIO:  0.017300000 +- 0.000500000  (Hel)
# new: REDSHIFT_HELIO: 0.01737 +- 0.000070 (HEL)
# old: REDSHIFT_CMB:  0.016590634 +- 0.000500000  (CMB)
# new: REDSHIFT_CMB: 0.01886 +- 0.000043 (CMB)
# old: REDSHIFT_FINAL:  0.016590634 +- 0.000500000  (CMB)
# new: REDSHIFT_FINAL: 0.01886 +- 0.000043 (CMB)
#    CFA4_p1_2009ad.dat
# old: REDSHIFT_HELIO:  0.028386 +- 0.000500000  (Hel)
# new: REDSHIFT_HELIO: 0.02840 +- 0.000003 (HEL)
# old: REDSHIFT_CMB:  0.028324276039 +- 0.000500000  (CMB)
# new: REDSHIFT_CMB: 0.02869 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.028324276039 +- 0.000500000  (CMB)
# new: REDSHIFT_FINAL: 0.02869 +- 0.000500 (CMB)
#    CFA4_p1_2009al.dat
# old: REDSHIFT_HELIO:  0.022089 +- 0.000500000  (Hel)
# new: REDSHIFT_HELIO: 0.02211 +- 0.000080 (HEL)
# old: REDSHIFT_CMB:  0.0232754004227 +- 0.000500000  (CMB)
# new: REDSHIFT_CMB: 0.02337 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0232754004227 +- 0.000500000  (CMB)
# new: REDSHIFT_FINAL: 0.02337 +- 0.000500 (CMB)
#    CFA4_p1_2009an.dat
# old: REDSHIFT_HELIO:  0.00922 +- 0.000500000  (Hel)
# new: REDSHIFT_HELIO: 0.00922 +- 0.000007 (HEL)
# old: REDSHIFT_CMB:  0.00956075682957 +- 0.000500000  (CMB)
# new: REDSHIFT_CMB: 0.01070 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.00956075682957 +- 0.000500000  (CMB)
# new: REDSHIFT_FINAL: 0.01070 +- 0.000500 (CMB)
#    CFA4_p1_2009bv.dat
# old: REDSHIFT_HELIO:  0.03661 +- 0.000500000  (Hel)
# new: REDSHIFT_HELIO: 0.03658 +- 0.000017 (HEL)
# old: REDSHIFT_CMB:  0.0373934866247 +- 0.000500000  (CMB)
# new: REDSHIFT_CMB: 0.03849 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0373934866247 +- 0.000500000  (CMB)
# new: REDSHIFT_FINAL: 0.03849 +- 0.000500 (CMB)
#    CFA4_p1_2009D.dat
# old: REDSHIFT_HELIO:  0.025054 +- 0.000500000  (Hel)
# new: REDSHIFT_HELIO: 0.02501 +- 0.000033 (HEL)
# old: REDSHIFT_CMB:  0.0247172877315 +- 0.000500000  (CMB)
# new: REDSHIFT_CMB: 0.02427 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0247172877315 +- 0.000500000  (CMB)
# new: REDSHIFT_FINAL: 0.02427 +- 0.000500 (CMB)
#    CFA4_p1_2009Y.dat
# old: REDSHIFT_HELIO:  0.009467 +- 0.000500000  (Hel)
# new: REDSHIFT_HELIO: 0.00932 +- 0.000027 (HEL)
# old: REDSHIFT_CMB:  0.0102244714285 +- 0.000500000  (CMB)
# new: REDSHIFT_CMB: 0.00943 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0102244714285 +- 0.000500000  (CMB)
# new: REDSHIFT_FINAL: 0.00943 +- 0.000500 (CMB)
#
# 70 SNe were updated their zcmb values peacefully :)
# 0 SNe are not in the metadata file.
#
# #-------- PS1s_CFA4_p2_RS14 ---------
#    CFA4_p2_2010ai.dat
# old: REDSHIFT_HELIO:  0.01828 +- 0.000500000  (Hel)
# new: REDSHIFT_HELIO: 0.01837 +- 0.000123 (HEL)
# old: REDSHIFT_CMB:  0.0191755323333 +- 0.000500000  (CMB)
# new: REDSHIFT_CMB: 0.02390 +- 0.000180 (CMB)
# old: REDSHIFT_FINAL: 0.0191755323333 +- 0.000500000  (CMB)
# new: REDSHIFT_FINAL: 0.02390 +- 0.000180 (CMB)
#
# 71 SNe were updated their zcmb values peacefully :)
# 0 SNe are not in the metadata file.
#
# #-------- PS1s_CSPDR2_V_RS14 ---------
#    CSPDR2_2004eo.dat
# old: REDSHIFT_HELIO:  0.016208 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.01562 +- 0.000003 (HEL)
# old: REDSHIFT_CMB:  0.0152520986553 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.01521 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0152520986553 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01521 +- 0.000500 (CMB)
#    CSPDR2_2004ey.dat
# old: REDSHIFT_HELIO:  0.0143 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.01584 +- 0.000003 (HEL)
# old: REDSHIFT_CMB:  0.0131503387813 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.01540 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0131503387813 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01540 +- 0.000500 (CMB)
#    CSPDR2_2005el.dat
# old: REDSHIFT_HELIO:  0.01488 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.01491 +- 0.000017 (HEL)
# old: REDSHIFT_CMB:  0.0148659909611 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.01526 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0148659909611 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01526 +- 0.000500 (CMB)
#    CSPDR2_2005iq.dat
# old: REDSHIFT_HELIO:  0.033696 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.03404 +- 0.000123 (HEL)
# old: REDSHIFT_CMB:  0.0326052156721 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.03355 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0326052156721 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.03355 +- 0.000500 (CMB)
#    CSPDR2_2005kc.dat
# old: REDSHIFT_HELIO:  0.01386 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.01509 +- 0.000003 (HEL)
# old: REDSHIFT_CMB:  0.0126401990505 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.01449 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0126401990505 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01449 +- 0.000500 (CMB)
#    CSPDR2_2005ki.dat
# old: REDSHIFT_HELIO:  0.01946 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.01946 +- 0.000010 (HEL)
# old: REDSHIFT_CMB:  0.0206361673558 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.02028 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0206361673558 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.02028 +- 0.000500 (CMB)
#    CSPDR2_2006ax.dat
# old: REDSHIFT_HELIO:  0.017982 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.01672 +- 0.000020 (HEL)
# old: REDSHIFT_CMB:  0.019211718677 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.01797 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.019211718677 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01797 +- 0.000500 (CMB)
#    CSPDR2_2006bh.dat
# old: REDSHIFT_HELIO:  0.01094 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.01085 +- 0.000013 (HEL)
# old: REDSHIFT_CMB:  0.0105938447996 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.01075 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0105938447996 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01075 +- 0.000500 (CMB)
#    CSPDR2_2006bt.dat
# old: REDSHIFT_HELIO:  0.03208 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.03208 +- 0.000007 (HEL)
# old: REDSHIFT_CMB:  0.0323999612884 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.03072 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0323999612884 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.03072 +- 0.000500 (CMB)
#    CSPDR2_2006kf.dat
# old: REDSHIFT_HELIO:  0.020774 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.02004 +- 0.000010 (HEL)
# old: REDSHIFT_CMB:  0.0202876519931 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.01942 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0202876519931 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01942 +- 0.000500 (CMB)
#    CSPDR2_2007A.dat
# old: REDSHIFT_HELIO:  0.0167 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.01765 +- 0.000087 (HEL)
# old: REDSHIFT_CMB:  0.0155308710897 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.01722 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0155308710897 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01722 +- 0.000500 (CMB)
#    CSPDR2_2007af.dat
# old: REDSHIFT_HELIO:  0.0055 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.00546 +- 0.000013 (HEL)
# old: REDSHIFT_CMB:  0.00632897411407 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.00556 +- 0.000177 (CMB)
# old: REDSHIFT_FINAL: 0.00632897411407 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.00556 +- 0.000177 (CMB)
#    CSPDR2_2007ai.dat
# old: REDSHIFT_HELIO:  0.032032 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.03166 +- 0.000137 (HEL)
# old: REDSHIFT_CMB:  0.0323789919452 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.03274 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0323789919452 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.03274 +- 0.000500 (CMB)
#    CSPDR2_2007as.dat
# old: REDSHIFT_HELIO:  0.0176 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.01757 +- 0.000460 (HEL)
# old: REDSHIFT_CMB:  0.0179369277292 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.01836 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0179369277292 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01836 +- 0.000500 (CMB)
#    CSPDR2_2007bc.dat
# old: REDSHIFT_HELIO:  0.02075 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.02075 +- 0.000007 (HEL)
# old: REDSHIFT_CMB:  0.0218434502132 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.02112 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0218434502132 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.02112 +- 0.000500 (CMB)
#    CSPDR2_2007bd.dat
# old: REDSHIFT_HELIO:  0.032 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.03044 +- 0.000100 (HEL)
# old: REDSHIFT_CMB:  0.0329417629686 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.03108 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0329417629686 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.03108 +- 0.000500 (CMB)
#    CSPDR2_2007ca.dat
# old: REDSHIFT_HELIO:  0.015161 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.01407 +- 0.000010 (HEL)
# old: REDSHIFT_CMB:  0.0161737648561 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.01447 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0161737648561 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01447 +- 0.000500 (CMB)
#    CSPDR2_2007jg.dat
# old: REDSHIFT_HELIO:  0.0371 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.03707 +- 0.000013 (HEL)
# old: REDSHIFT_CMB:  0.0365714358281 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.03796 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0365714358281 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.03796 +- 0.000500 (CMB)
#    CSPDR2_2007le.dat
# old: REDSHIFT_HELIO:  0.006736 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.00673 +- 0.000003 (HEL)
# old: REDSHIFT_CMB:  0.00553671297246 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.00647 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.00553671297246 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.00647 +- 0.000500 (CMB)
#    CSPDR2_2008bc.dat
# old: REDSHIFT_HELIO:  0.015087 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.01509 +- 0.000120 (HEL)
# old: REDSHIFT_CMB:  0.0157170191024 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.01560 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0157170191024 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01560 +- 0.000500 (CMB)
#    CSPDR2_2008gp.dat
# old: REDSHIFT_HELIO:  0.033523 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.03303 +- 0.000070 (HEL)
# old: REDSHIFT_CMB:  0.0329583758875 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.03346 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0329583758875 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.03346 +- 0.000500 (CMB)
#    CSPDR2_2008hv.dat
# old: REDSHIFT_HELIO:  0.012584 +- 0.0010  (Hel)
# new: REDSHIFT_HELIO: 0.01259 +- 0.000007 (HEL)
# old: REDSHIFT_CMB:  0.0136242033977 +- 0.0010  (CMB)
# new: REDSHIFT_CMB: 0.01396 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.0136242033977 +- 0.0010  (CMB)
# new: REDSHIFT_FINAL: 0.01396 +- 0.000500 (CMB)
#    sn2008ar_CSP_Wstd_27_5_snana.dat
# old: REDSHIFT_HELIO: 0.02617 +- 0.000010 (HEL)
# new: REDSHIFT_HELIO: 0.02617 +- 0.000010 (HEL)
# old: REDSHIFT_CMB: 0.02895 +- 0.000500 (CMB)
# new: REDSHIFT_CMB: 0.02895 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.02895 +- 0.000500 (CMB)
# new: REDSHIFT_FINAL: 0.02895 +- 0.000500 (CMB)
#    sn2008bf_CSP_Wstd_27_5_snana.dat
# old: REDSHIFT_HELIO: 0.02350 +- 0.000167 (HEL)
# new: REDSHIFT_HELIO: 0.02350 +- 0.000167 (HEL)
# old: REDSHIFT_CMB: 0.02538 +- 0.000500 (CMB)
# new: REDSHIFT_CMB: 0.02538 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.02538 +- 0.000500 (CMB)
# new: REDSHIFT_FINAL: 0.02538 +- 0.000500 (CMB)
#    sn2008hj_CSP_Wstd_27_5_snana.dat
# old: REDSHIFT_HELIO: 0.03789 +- 0.000130 (HEL)
# new: REDSHIFT_HELIO: 0.03789 +- 0.000130 (HEL)
# old: REDSHIFT_CMB: 0.03716 +- 0.000500 (CMB)
# new: REDSHIFT_CMB: 0.03716 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.03716 +- 0.000500 (CMB)
# new: REDSHIFT_FINAL: 0.03716 +- 0.000500 (CMB)
#    sn2009aa_CSP_Wstd_27_5_snana.dat
# old: REDSHIFT_HELIO: 0.02731 +- 0.000047 (HEL)
# new: REDSHIFT_HELIO: 0.02731 +- 0.000047 (HEL)
# old: REDSHIFT_CMB: 0.02868 +- 0.000500 (CMB)
# new: REDSHIFT_CMB: 0.02868 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.02868 +- 0.000500 (CMB)
# new: REDSHIFT_FINAL: 0.02868 +- 0.000500 (CMB)
#    sn2009ad_CSP_Wstd_27_5_snana.dat
# old: REDSHIFT_HELIO: 0.02840 +- 0.000003 (HEL)
# new: REDSHIFT_HELIO: 0.02840 +- 0.000003 (HEL)
# old: REDSHIFT_CMB: 0.02869 +- 0.000500 (CMB)
# new: REDSHIFT_CMB: 0.02869 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.02869 +- 0.000500 (CMB)
# new: REDSHIFT_FINAL: 0.02869 +- 0.000500 (CMB)
#    sn2009ag_CSP_Wstd_27_5_snana.dat
# old: REDSHIFT_HELIO: 0.00864 +- 0.000007 (HEL)
# new: REDSHIFT_HELIO: 0.00864 +- 0.000007 (HEL)
# old: REDSHIFT_CMB: 0.01019 +- 0.000500 (CMB)
# new: REDSHIFT_CMB: 0.01019 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.01019 +- 0.000500 (CMB)
# new: REDSHIFT_FINAL: 0.01019 +- 0.000500 (CMB)
#    sn2009cz_CSP_Wstd_27_5_snana.dat
# old: REDSHIFT_HELIO: 0.02116 +- 0.000010 (HEL)
# new: REDSHIFT_HELIO: 0.02116 +- 0.000010 (HEL)
# old: REDSHIFT_CMB: 0.02184 +- 0.000500 (CMB)
# new: REDSHIFT_CMB: 0.02184 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.02184 +- 0.000500 (CMB)
# new: REDSHIFT_FINAL: 0.02184 +- 0.000500 (CMB)
#    sn2009D__CSP_Wstd_27_5_snana.dat
# old: REDSHIFT_HELIO: 0.02501 +- 0.000033 (HEL)
# new: REDSHIFT_HELIO: 0.02501 +- 0.000033 (HEL)
# old: REDSHIFT_CMB: 0.02427 +- 0.000500 (CMB)
# new: REDSHIFT_CMB: 0.02427 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.02427 +- 0.000500 (CMB)
# new: REDSHIFT_FINAL: 0.02427 +- 0.000500 (CMB)
#    sn2009Y__CSP_Wstd_27_5_snana.dat
# old: REDSHIFT_HELIO: 0.00932 +- 0.000027 (HEL)
# new: REDSHIFT_HELIO: 0.00932 +- 0.000027 (HEL)
# old: REDSHIFT_CMB: 0.00943 +- 0.000500 (CMB)
# new: REDSHIFT_CMB: 0.00943 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.00943 +- 0.000500 (CMB)
# new: REDSHIFT_FINAL: 0.00943 +- 0.000500 (CMB)
#
# 102 SNe were updated their zcmb values peacefully :)
# 0 SNe are not in the metadata file.
#
# #-------- SNLS3year_CFA3_KEPLERCAM ---------
#    SNLS3year_CFA3_KEPLERCAM_2006D.dat
# old: REDSHIFT_HELIO: 0.008526 +- 0.000017    (HELIO)
# new: REDSHIFT_HELIO: 0.00853 +- 0.000017 (HEL)
# old: REDSHIFT_CMB: 0.009647 +- 0.000017    (CMB)
# new: REDSHIFT_CMB: 0.00898 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.009647 +- 0.000017    (CMB)
# new: REDSHIFT_FINAL: 0.00898 +- 0.000500 (CMB)
#    SNLS3year_CFA3_KEPLERCAM_2006lf.dat
# old: REDSHIFT_HELIO: 0.013206 +- 0.000023    (HELIO)
# new: REDSHIFT_HELIO: 0.01319 +- 0.000017 (HEL)
# old: REDSHIFT_CMB: 0.012972 +- 0.000023    (CMB)
# new: REDSHIFT_CMB: 0.01210 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.012972 +- 0.000023    (CMB)
# new: REDSHIFT_FINAL: 0.01210 +- 0.000500 (CMB)
#
# 104 SNe were updated their zcmb values peacefully :)
# 0 SNe are not in the metadata file.
#
# #-------- SNLS3year_JRK07 ---------
#    SNLS3year_JRK07_1998bu.dat
# old: REDSHIFT_HELIO: 0.002992 +- 0.000013    (HELIO)
# new: REDSHIFT_HELIO: 0.00296 +- 0.000003 (HEL)
# old: REDSHIFT_CMB: 0.004156 +- 0.000013    (CMB)
# new: REDSHIFT_CMB: 0.00253 +- 0.000233 (CMB)
# old: REDSHIFT_FINAL: 0.004156 +- 0.000013    (CMB)
# new: REDSHIFT_FINAL: 0.00253 +- 0.000233 (CMB)
#    SNLS3year_JRK07_1999ek.dat
# old: REDSHIFT_HELIO: 0.017522 +- 0.000030    (HELIO)
# new: REDSHIFT_HELIO: 0.01757 +- 0.000007 (HEL)
# old: REDSHIFT_CMB: 0.017605 +- 0.000030    (CMB)
# new: REDSHIFT_CMB: 0.01781 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.017605 +- 0.000030    (CMB)
# new: REDSHIFT_FINAL: 0.01781 +- 0.000500 (CMB)
#    SNLS3year_JRK07_2000E.dat
# old: REDSHIFT_HELIO: 0.00475 +- 0.000005    (HELIO)
# new: REDSHIFT_HELIO: 0.00475 +- 0.000003 (HEL)
# old: REDSHIFT_CMB: 0.004223 +- 0.000005    (CMB)
# new: REDSHIFT_CMB: 0.00562 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.004223 +- 0.000005    (CMB)
# new: REDSHIFT_FINAL: 0.00562 +- 0.000500 (CMB)
#    SNLS3year_JRK07_2001bt.dat
# old: REDSHIFT_HELIO: 0.01464 +- 0.000033    (HELIO)
# new: REDSHIFT_HELIO: 0.01464 +- 0.000033 (HEL)
# old: REDSHIFT_CMB: 0.014448 +- 0.000033    (CMB)
# new: REDSHIFT_CMB: 0.01421 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.014448 +- 0.000033    (CMB)
# new: REDSHIFT_FINAL: 0.01421 +- 0.000500 (CMB)
#    SNLS3year_JRK07_2001cz.dat
# old: REDSHIFT_HELIO: 0.01538 +- 0.000030    (HELIO)
# new: REDSHIFT_HELIO: 0.01549 +- 0.000027 (HEL)
# old: REDSHIFT_CMB: 0.016346 +- 0.000030    (CMB)
# new: REDSHIFT_CMB: 0.01709 +- 0.000500 (CMB)
# old: REDSHIFT_FINAL: 0.016346 +- 0.000030    (CMB)
# new: REDSHIFT_FINAL: 0.01709 +- 0.000500 (CMB)
#    SNLS3year_JRK07_2001el.dat
# old: REDSHIFT_HELIO: 0.003896 +- 0.000007    (HELIO)
# new: REDSHIFT_HELIO: 0.00390 +- 0.000007 (HEL)
# old: REDSHIFT_CMB: 0.003676 +- 0.000007    (CMB)
# new: REDSHIFT_CMB: 0.00447 +- 0.000140 (CMB)
# old: REDSHIFT_FINAL: 0.003676 +- 0.000007    (CMB)
# new: REDSHIFT_FINAL: 0.00447 +- 0.000140 (CMB)
#    SNLS3year_JRK07_2002dj.dat
# old: REDSHIFT_HELIO: 0.009393 +- 0.000003    (HELIO)
# new: REDSHIFT_HELIO: 0.00939 +- 0.000003 (HEL)
# old: REDSHIFT_CMB: 0.010444 +- 0.000003    (CMB)
# new: REDSHIFT_CMB: 0.00827 +- 0.001524 (CMB)
# old: REDSHIFT_FINAL: 0.010444 +- 0.000003    (CMB)
# new: REDSHIFT_FINAL: 0.00827 +- 0.001524 (CMB)
#
# 111 SNe were updated their zcmb values peacefully :)
# 0 SNe are not in the metadata file.
